# %%
import pandas as pd
import altair as alt
from ecostyles import EcoStyles

# %%
# ---- data (embedded: 193 economies, WEO 2010-2019 averages) ----
data = [
    ('Afghanistan', 7.7, 4.82, 'Emerging & developing'),
    ('Albania', 67.6, 2.56, 'Emerging & developing'),
    ('Algeria', 16.5, 2.78, 'Emerging & developing'),
    ('Andorra', 38.8, 0.1, 'Emerging & developing'),
    ('Angola', 50.6, 2.52, 'Emerging & developing'),
    ('Antigua and Barbuda', 84.4, 1.33, 'Emerging & developing'),
    ('Argentina', 54.9, 1.38, 'Emerging & developing'),
    ('Armenia', 48.2, 4.48, 'Emerging & developing'),
    ('Aruba', 69.8, 2.03, 'Emerging & developing'),
    ('Australia', 34.3, 2.61, 'Advanced'),
    ('Austria', 81.1, 1.58, 'Advanced'),
    ('Azerbaijan', 12.8, 1.81, 'Emerging & developing'),
    ('Bahamas, The', 47.6, 1.04, 'Emerging & developing'),
    ('Bahrain', 59.2, 3.51, 'Emerging & developing'),
    ('Bangladesh', 29.1, 6.62, 'Emerging & developing'),
    ('Barbados', 110.8, -0.3, 'Emerging & developing'),
    ('Belarus', 45.6, 1.87, 'Emerging & developing'),
    ('Belgium', 103.0, 1.54, 'Advanced'),
    ('Belize', 69.3, 1.93, 'Emerging & developing'),
    ('Benin', 29.1, 4.79, 'Emerging & developing'),
    ('Bhutan', 86.8, 6.13, 'Emerging & developing'),
    ('Bolivia', 36.4, 4.62, 'Emerging & developing'),
    ('Bosnia and Herzegovina', 41.5, 2.2, 'Emerging & developing'),
    ('Botswana', 23.6, 4.71, 'Emerging & developing'),
    ('Brazil', 71.0, 1.44, 'Emerging & developing'),
    ('Brunei Darussalam', 2.3, 0.51, 'Emerging & developing'),
    ('Bulgaria', 20.2, 2.0, 'Emerging & developing'),
    ('Burkina Faso', 30.3, 6.02, 'Emerging & developing'),
    ('Burundi', 45.3, 2.2, 'Emerging & developing'),
    ('Cabo Verde', 98.6, 2.85, 'Emerging & developing'),
    ('Cambodia', 23.2, 7.52, 'Emerging & developing'),
    ('Cameroon', 26.3, 4.28, 'Emerging & developing'),
    ('Canada', 88.5, 2.24, 'Advanced'),
    ('Central African Republic', 42.4, -0.17, 'Emerging & developing'),
    ('Chad', 30.0, 4.1, 'Emerging & developing'),
    ('Chile', 17.6, 3.34, 'Emerging & developing'),
    ("China, People's Republic of", 43.6, 7.68, 'Emerging & developing'),
    ('Colombia', 44.0, 3.72, 'Emerging & developing'),
    ('Comoros', 19.4, 3.13, 'Emerging & developing'),
    ('Congo, Dem. Rep. of the', 11.2, 5.87, 'Emerging & developing'),
    ('Congo, Republic of', 58.0, 1.26, 'Emerging & developing'),
    ('Costa Rica', 40.3, 3.84, 'Emerging & developing'),
    ('Croatia', 73.3, 1.08, 'Emerging & developing'),
    ('Cyprus', 92.3, 1.88, 'Advanced'),
    ('Czech Republic', 37.6, 2.51, 'Advanced'),
    ("Côte d'Ivoire", 33.7, 6.1, 'Emerging & developing'),
    ('Denmark', 44.5, 1.75, 'Advanced'),
    ('Djibouti', 35.3, 5.86, 'Emerging & developing'),
    ('Dominica', 76.8, 0.57, 'Emerging & developing'),
    ('Dominican Republic', 45.6, 5.6, 'Emerging & developing'),
    ('Ecuador', 33.9, 3.63, 'Emerging & developing'),
    ('Egypt', 81.4, 3.9, 'Emerging & developing'),
    ('El Salvador', 72.5, 2.46, 'Emerging & developing'),
    ('Equatorial Guinea', 23.4, -3.31, 'Emerging & developing'),
    ('Eritrea', 232.2, 5.25, 'Emerging & developing'),
    ('Estonia', 9.8, 3.67, 'Advanced'),
    ('Eswatini', 18.8, 3.2, 'Emerging & developing'),
    ('Ethiopia', 48.3, 9.62, 'Emerging & developing'),
    ('Fiji', 47.4, 4.11, 'Emerging & developing'),
    ('Finland', 62.0, 1.15, 'Advanced'),
    ('France', 94.8, 1.41, 'Advanced'),
    ('Gabon', 42.4, 4.09, 'Emerging & developing'),
    ('Gambia, The', 67.3, 2.87, 'Emerging & developing'),
    ('Georgia', 33.9, 5.41, 'Emerging & developing'),
    ('Germany', 71.4, 1.98, 'Advanced'),
    ('Ghana', 48.4, 6.66, 'Emerging & developing'),
    ('Greece', 177.0, -1.97, 'Advanced'),
    ('Grenada', 87.8, 2.84, 'Emerging & developing'),
    ('Guatemala', 25.0, 3.55, 'Emerging & developing'),
    ('Guinea', 41.1, 6.02, 'Emerging & developing'),
    ('Guinea-Bissau', 55.6, 4.08, 'Emerging & developing'),
    ('Guyana', 41.4, 3.82, 'Emerging & developing'),
    ('Haiti', 23.9, 1.28, 'Emerging & developing'),
    ('Honduras', 35.1, 3.64, 'Emerging & developing'),
    ('Hong Kong SAR', 0.3, 2.87, 'Advanced'),
    ('Hungary', 74.9, 2.89, 'Emerging & developing'),
    ('Iceland', 101.2, 2.52, 'Advanced'),
    ('India', 69.9, 6.65, 'Emerging & developing'),
    ('Indonesia', 26.7, 5.44, 'Emerging & developing'),
    ('Iran', 26.4, 1.33, 'Emerging & developing'),
    ('Iraq', 43.9, 6.15, 'Emerging & developing'),
    ('Ireland', 86.3, 6.31, 'Advanced'),
    ('Israel', 63.9, 3.99, 'Advanced'),
    ('Italy', 130.1, 0.22, 'Advanced'),
    ('Jamaica', 117.8, 1.11, 'Emerging & developing'),
    ('Japan', 198.6, 1.3, 'Advanced'),
    ('Jordan', 65.9, 2.48, 'Emerging & developing'),
    ('Kazakhstan', 16.2, 4.44, 'Emerging & developing'),
    ('Kenya', 45.7, 5.04, 'Emerging & developing'),
    ('Kiribati', 14.2, 4.82, 'Emerging & developing'),
    ('Korea, Republic of', 36.1, 3.47, 'Advanced'),
    ('Kosovo', 12.0, 4.6, 'Emerging & developing'),
    ('Kuwait', 8.0, 1.92, 'Emerging & developing'),
    ('Kyrgyz Republic', 55.0, 4.13, 'Emerging & developing'),
    ('Lao P.D.R.', 53.6, 7.15, 'Emerging & developing'),
    ('Latvia', 42.1, 2.56, 'Advanced'),
    ('Lebanon', 144.1, 1.23, 'Emerging & developing'),
    ('Lesotho', 42.7, 1.83, 'Emerging & developing'),
    ('Liberia', 28.2, 3.16, 'Emerging & developing'),
    ('Liechtenstein', 0.5, 2.07, 'Emerging & developing'),
    ('Lithuania', 38.4, 3.85, 'Advanced'),
    ('Luxembourg', 20.8, 2.51, 'Advanced'),
    ('Macao SAR', 0.0, 5.6, 'Advanced'),
    ('Madagascar', 37.5, 2.94, 'Emerging & developing'),
    ('Malawi', 33.1, 4.37, 'Emerging & developing'),
    ('Malaysia', 54.8, 5.34, 'Emerging & developing'),
    ('Maldives', 60.1, 6.55, 'Emerging & developing'),
    ('Mali', 26.0, 4.67, 'Emerging & developing'),
    ('Malta', 55.9, 6.32, 'Advanced'),
    ('Marshall Islands', 32.0, 3.03, 'Emerging & developing'),
    ('Mauritania', 50.2, 4.07, 'Emerging & developing'),
    ('Mauritius', 61.0, 3.76, 'Emerging & developing'),
    ('Mexico', 47.6, 2.34, 'Emerging & developing'),
    ('Micronesia, Fed. States of', 25.7, 0.95, 'Emerging & developing'),
    ('Moldova', 32.4, 4.21, 'Emerging & developing'),
    ('Mongolia', 56.0, 7.92, 'Emerging & developing'),
    ('Montenegro', 63.0, 2.77, 'Emerging & developing'),
    ('Morocco', 56.1, 3.51, 'Emerging & developing'),
    ('Mozambique', 74.1, 5.66, 'Emerging & developing'),
    ('Myanmar', 42.3, 6.5, 'Emerging & developing'),
    ('Namibia', 36.0, 3.15, 'Emerging & developing'),
    ('Nauru', 141.6, 6.79, 'Emerging & developing'),
    ('Nepal', 30.3, 5.01, 'Emerging & developing'),
    ('Netherlands', 60.0, 1.56, 'Advanced'),
    ('New Zealand', 32.7, 2.9, 'Advanced'),
    ('Nicaragua', 32.2, 3.46, 'Emerging & developing'),
    ('Niger', 26.6, 6.16, 'Emerging & developing'),
    ('Nigeria', 15.2, 3.82, 'Emerging & developing'),
    ('North Macedonia', 35.6, 2.63, 'Emerging & developing'),
    ('Norway', 34.5, 1.72, 'Advanced'),
    ('Oman', 20.4, 3.13, 'Emerging & developing'),
    ('Pakistan', 61.8, 3.79, 'Emerging & developing'),
    ('Palau', 28.3, 1.32, 'Emerging & developing'),
    ('Panama', 35.1, 6.11, 'Emerging & developing'),
    ('Papua New Guinea', 27.6, 5.3, 'Emerging & developing'),
    ('Paraguay', 17.1, 4.32, 'Emerging & developing'),
    ('Peru', 23.4, 4.5, 'Emerging & developing'),
    ('Philippines', 41.2, 6.39, 'Emerging & developing'),
    ('Poland', 52.0, 3.8, 'Emerging & developing'),
    ('Portugal', 123.1, 0.81, 'Advanced'),
    ('Puerto Rico', 51.4, -1.02, 'Advanced'),
    ('Qatar', 40.0, 5.29, 'Emerging & developing'),
    ('Romania', 36.8, 3.06, 'Emerging & developing'),
    ('Russian Federation', 13.1, 2.0, 'Emerging & developing'),
    ('Rwanda', 33.7, 7.1, 'Emerging & developing'),
    ('Saint Kitts and Nevis', 82.5, 2.15, 'Emerging & developing'),
    ('Saint Lucia', 59.4, 1.33, 'Emerging & developing'),
    ('Saint Vincent and the Grenadines', 69.9, 1.21, 'Emerging & developing'),
    ('Samoa', 48.8, 2.06, 'Emerging & developing'),
    ('San Marino', 30.8, -1.44, 'Advanced'),
    ('Saudi Arabia', 9.1, 4.2, 'Emerging & developing'),
    ('Senegal', 47.7, 4.83, 'Emerging & developing'),
    ('Serbia', 55.9, 1.61, 'Emerging & developing'),
    ('Seychelles', 68.0, 6.53, 'Emerging & developing'),
    ('Sierra Leone', 32.9, 4.71, 'Emerging & developing'),
    ('Singapore', 105.7, 4.94, 'Advanced'),
    ('Slovak Republic', 49.6, 3.08, 'Advanced'),
    ('Slovenia', 66.6, 1.94, 'Advanced'),
    ('Solomon Islands', 11.5, 4.08, 'Emerging & developing'),
    ('South Africa', 43.5, 1.76, 'Emerging & developing'),
    ('South Sudan, Republic of', 50.9, -5.24, 'Emerging & developing'),
    ('Spain', 92.7, 1.1, 'Advanced'),
    ('Sri Lanka', 73.5, 5.37, 'Emerging & developing'),
    ('Sudan', 124.0, -0.4, 'Emerging & developing'),
    ('Suriname', 45.1, 1.63, 'Emerging & developing'),
    ('Sweden', 40.5, 2.48, 'Advanced'),
    ('Switzerland', 40.7, 1.96, 'Advanced'),
    ('São Tomé and Príncipe', 89.0, 3.35, 'Emerging & developing'),
    ('Taiwan Province of China', 36.3, 3.67, 'Advanced'),
    ('Tajikistan', 37.5, 7.05, 'Emerging & developing'),
    ('Tanzania', 35.7, 6.66, 'Emerging & developing'),
    ('Thailand', 41.5, 3.62, 'Emerging & developing'),
    ('Timor-Leste', 3.5, 3.23, 'Emerging & developing'),
    ('Togo', 47.3, 5.43, 'Emerging & developing'),
    ('Tonga', 48.5, 2.2, 'Emerging & developing'),
    ('Trinidad and Tobago', 44.6, 0.18, 'Emerging & developing'),
    ('Tunisia', 54.6, 1.98, 'Emerging & developing'),
    ('Turkmenistan', 18.1, 8.96, 'Emerging & developing'),
    ('Tuvalu', 15.5, 4.02, 'Emerging & developing'),
    ('Türkiye, Republic of', 30.1, 5.91, 'Emerging & developing'),
    ('Uganda', 26.9, 5.53, 'Emerging & developing'),
    ('Ukraine', 56.1, 0.14, 'Emerging & developing'),
    ('United Arab Emirates', 19.0, 4.33, 'Emerging & developing'),
    ('United Kingdom', 84.3, 1.98, 'Advanced'),
    ('United States', 104.5, 2.4, 'Advanced'),
    ('Uruguay', 52.1, 2.92, 'Emerging & developing'),
    ('Uzbekistan', 10.0, 7.06, 'Emerging & developing'),
    ('Vanuatu', 28.5, 2.9, 'Emerging & developing'),
    ('Venezuela', 110.2, -8.06, 'Emerging & developing'),
    ('Vietnam', 42.2, 6.58, 'Emerging & developing'),
    ('West Bank and Gaza', 31.1, 4.26, 'Emerging & developing'),
    ('Zambia', 49.9, 4.89, 'Emerging & developing'),
    ('Zimbabwe', 35.1, 6.19, 'Emerging & developing'),
]

df = pd.DataFrame(data, columns=["country", "debt", "growth", "group"])

# ---- enable EO theme ----
styles = EcoStyles()
styles.register_and_enable_theme()          # match your usual call / theme name

# ---- scatter ----
points = (
    alt.Chart(df)
    .mark_point(filled=True, size=45, opacity=0.6)
    .encode(
        x=alt.X("debt:Q",
                title="Gross government debt (% of GDP), 2010-2019 avg",
                scale=alt.Scale(domain=[0, 250]),
                axis=alt.Axis(grid=False, tickCount=6)),
        y=alt.Y("growth:Q",
        title="Real GDP growth (% p.a.), 2010-2019 avg",
        axis=alt.Axis(grid=False, tickCount=6,
                      titleY=-8, titleX=0)),
        color=alt.Color("group:N",
        scale=alt.Scale(domain=["Advanced", "Emerging & developing"],
                        range=["#E6224B", "#36B7B4"]),
        legend=alt.Legend(orient="none", legendX=420, legendY=10,
                          direction="vertical", title=None)),
        tooltip=[alt.Tooltip("country:N", title="Country"),
                 alt.Tooltip("debt:Q", title="Debt % GDP", format=".1f"),
                 alt.Tooltip("growth:Q", title="Growth %", format=".1f")],
    )
)

zero = (
    alt.Chart(pd.DataFrame({"y": [0]}))
    .mark_rule(color="#676A86", strokeDash=[4, 3], opacity=0.7, strokeWidth=1)
    .encode(y="y:Q")
)

chart = (points + zero).properties(
    width=600, height=440,
    title=alt.Title(
        "Higher debt, slower growth - but the cloud is wide",
        subtitle="Gross government debt vs real GDP growth, 2010-2019 averages, by economy",
    ),
)

styles.save(chart, name="debt_growth_scatter",
            source="IMF World Economic Outlook", svg=True)
chart
# Out:
# alt.LayerChart(...)
