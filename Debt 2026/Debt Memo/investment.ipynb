# %%
import pandas as pd
import altair as alt
from ecostyles import EcoStyles

# %%
# ---- data (156 economies; debt = WEO gross debt %GDP, inv = World Bank gross capital formation %GDP; 2010-2019 avgs) ----
data = [
    ('Albania', 67.56, 28.81, 'Emerging & developing'),
    ('Algeria', 16.52, 45.76, 'Emerging & developing'),
    ('Angola', 50.56, 27.7, 'Emerging & developing'),
    ('Argentina', 54.87, 17.09, 'Emerging & developing'),
    ('Armenia', 48.19, 23.58, 'Emerging & developing'),
    ('Aruba', 69.8, 23.38, 'Emerging & developing'),
    ('Australia', 34.31, 25.85, 'Advanced'),
    ('Austria', 81.13, 24.41, 'Advanced'),
    ('Azerbaijan', 12.8, 23.22, 'Emerging & developing'),
    ('Bahrain', 59.22, 29.08, 'Emerging & developing'),
    ('Bangladesh', 29.09, 29.3, 'Emerging & developing'),
    ('Belarus', 45.58, 32.74, 'Emerging & developing'),
    ('Belgium', 103.01, 23.85, 'Advanced'),
    ('Belize', 69.33, 15.48, 'Emerging & developing'),
    ('Benin', 29.06, 20.24, 'Emerging & developing'),
    ('Bhutan', 86.83, 58.82, 'Emerging & developing'),
    ('Bolivia', 36.4, 20.7, 'Emerging & developing'),
    ('Bosnia and Herzegovina', 41.48, 23.28, 'Emerging & developing'),
    ('Botswana', 23.6, 29.22, 'Emerging & developing'),
    ('Brazil', 70.95, 18.49, 'Emerging & developing'),
    ('Brunei Darussalam', 2.3, 33.4, 'Emerging & developing'),
    ('Bulgaria', 20.22, 21.0, 'Emerging & developing'),
    ('Burkina Faso', 30.33, 21.55, 'Emerging & developing'),
    ('Cabo Verde', 98.63, 32.79, 'Emerging & developing'),
    ('Cambodia', 23.16, 27.92, 'Emerging & developing'),
    ('Cameroon', 26.31, 18.93, 'Emerging & developing'),
    ('Canada', 88.55, 23.88, 'Advanced'),
    ('Central African Republic', 42.43, 19.28, 'Emerging & developing'),
    ('Chad', 29.97, 23.11, 'Emerging & developing'),
    ('Chile', 17.57, 25.4, 'Emerging & developing'),
    ('Colombia', 43.97, 22.43, 'Emerging & developing'),
    ('Comoros', 19.38, 14.91, 'Emerging & developing'),
    ('Costa Rica', 40.26, 18.82, 'Emerging & developing'),
    ('Croatia', 73.35, 19.88, 'Emerging & developing'),
    ('Cyprus', 92.28, 17.3, 'Advanced'),
    ('Denmark', 44.46, 20.41, 'Advanced'),
    ('Djibouti', 35.29, 14.96, 'Emerging & developing'),
    ('Dominican Republic', 45.6, 23.54, 'Emerging & developing'),
    ('Ecuador', 33.94, 22.86, 'Emerging & developing'),
    ('Egypt', 81.42, 16.98, 'Emerging & developing'),
    ('El Salvador', 72.46, 17.1, 'Emerging & developing'),
    ('Equatorial Guinea', 23.39, 24.91, 'Emerging & developing'),
    ('Estonia', 9.76, 25.92, 'Advanced'),
    ('Eswatini', 18.77, 17.73, 'Emerging & developing'),
    ('Ethiopia', 48.26, 32.72, 'Emerging & developing'),
    ('Fiji', 47.42, 21.07, 'Emerging & developing'),
    ('Finland', 62.02, 23.55, 'Advanced'),
    ('France', 94.81, 22.02, 'Advanced'),
    ('Gabon', 42.35, 26.63, 'Emerging & developing'),
    ('Georgia', 33.9, 25.34, 'Emerging & developing'),
    ('Germany', 71.43, 20.31, 'Advanced'),
    ('Ghana', 48.43, 20.79, 'Emerging & developing'),
    ('Greece', 177.01, 13.02, 'Advanced'),
    ('Guatemala', 24.97, 14.62, 'Emerging & developing'),
    ('Guinea', 41.12, 25.51, 'Emerging & developing'),
    ('Guinea-Bissau', 55.58, 18.64, 'Emerging & developing'),
    ('Haiti', 23.92, 18.35, 'Emerging & developing'),
    ('Honduras', 35.07, 23.92, 'Emerging & developing'),
    ('Hong Kong SAR', 0.3, 22.64, 'Advanced'),
    ('Hungary', 74.89, 23.38, 'Emerging & developing'),
    ('Iceland', 101.19, 18.11, 'Advanced'),
    ('India', 69.89, 34.17, 'Emerging & developing'),
    ('Indonesia', 26.74, 33.94, 'Emerging & developing'),
    ('Iran', 26.36, 36.21, 'Emerging & developing'),
    ('Iraq', 43.92, 18.1, 'Emerging & developing'),
    ('Ireland', 86.28, 27.22, 'Advanced'),
    ('Israel', 63.86, 23.08, 'Advanced'),
    ('Italy', 130.13, 18.37, 'Advanced'),
    ('Japan', 198.64, 25.86, 'Advanced'),
    ('Kazakhstan', 16.18, 25.89, 'Emerging & developing'),
    ('Kenya', 45.67, 21.35, 'Emerging & developing'),
    ('Kiribati', 14.19, 25.27, 'Emerging & developing'),
    ('Korea, Republic of', 36.09, 31.06, 'Advanced'),
    ('Kosovo', 12.04, 32.84, 'Emerging & developing'),
    ('Kuwait', 7.98, 20.64, 'Emerging & developing'),
    ('Kyrgyz Republic', 54.96, 33.05, 'Emerging & developing'),
    ('Lao P.D.R.', 53.59, 29.86, 'Emerging & developing'),
    ('Latvia', 42.08, 24.21, 'Advanced'),
    ('Lebanon', 144.13, 23.11, 'Emerging & developing'),
    ('Lesotho', 42.72, 28.88, 'Emerging & developing'),
    ('Lithuania', 38.39, 20.65, 'Advanced'),
    ('Luxembourg', 20.84, 18.48, 'Advanced'),
    ('Macao SAR', 0.0, 17.39, 'Advanced'),
    ('Madagascar', 37.53, 19.51, 'Emerging & developing'),
    ('Malaysia', 54.79, 24.52, 'Emerging & developing'),
    ('Maldives', 60.11, 39.08, 'Emerging & developing'),
    ('Mali', 25.97, 24.74, 'Emerging & developing'),
    ('Malta', 55.94, 19.68, 'Advanced'),
    ('Marshall Islands', 32.0, 26.0, 'Emerging & developing'),
    ('Mauritania', 50.23, 40.35, 'Emerging & developing'),
    ('Mauritius', 61.02, 20.4, 'Emerging & developing'),
    ('Mexico', 47.6, 23.45, 'Emerging & developing'),
    ('Moldova', 32.37, 24.05, 'Emerging & developing'),
    ('Mongolia', 56.02, 39.41, 'Emerging & developing'),
    ('Montenegro', 62.96, 23.54, 'Emerging & developing'),
    ('Morocco', 56.15, 31.59, 'Emerging & developing'),
    ('Mozambique', 74.08, 42.08, 'Emerging & developing'),
    ('Namibia', 36.0, 23.73, 'Emerging & developing'),
    ('Nepal', 30.26, 33.31, 'Emerging & developing'),
    ('Netherlands', 60.02, 19.9, 'Advanced'),
    ('New Zealand', 32.74, 22.62, 'Advanced'),
    ('Nicaragua', 32.23, 28.31, 'Emerging & developing'),
    ('Niger', 26.56, 31.32, 'Emerging & developing'),
    ('North Macedonia', 35.56, 30.12, 'Emerging & developing'),
    ('Norway', 34.45, 25.71, 'Advanced'),
    ('Oman', 20.37, 31.31, 'Emerging & developing'),
    ('Pakistan', 61.76, 15.63, 'Emerging & developing'),
    ('Palau', 28.31, 29.38, 'Emerging & developing'),
    ('Panama', 35.06, 40.74, 'Emerging & developing'),
    ('Paraguay', 17.14, 22.12, 'Emerging & developing'),
    ('Peru', 23.39, 23.2, 'Emerging & developing'),
    ('Philippines', 41.22, 22.74, 'Emerging & developing'),
    ('Poland', 52.0, 20.69, 'Emerging & developing'),
    ('Portugal', 123.14, 17.23, 'Advanced'),
    ('Qatar', 39.99, 36.24, 'Emerging & developing'),
    ('Romania', 36.8, 25.28, 'Emerging & developing'),
    ('Rwanda', 33.68, 22.82, 'Emerging & developing'),
    ('Samoa', 48.75, 30.87, 'Emerging & developing'),
    ('San Marino', 30.82, 18.32, 'Advanced'),
    ('Saudi Arabia', 9.1, 27.29, 'Emerging & developing'),
    ('Senegal', 47.74, 26.12, 'Emerging & developing'),
    ('Serbia', 55.91, 19.17, 'Emerging & developing'),
    ('Seychelles', 68.0, 29.78, 'Emerging & developing'),
    ('Sierra Leone', 32.89, 23.05, 'Emerging & developing'),
    ('Singapore', 105.66, 27.09, 'Advanced'),
    ('Slovak Republic', 49.61, 24.04, 'Advanced'),
    ('Slovenia', 66.61, 20.38, 'Advanced'),
    ('Solomon Islands', 11.46, 16.94, 'Emerging & developing'),
    ('South Africa', 43.55, 17.69, 'Emerging & developing'),
    ('Spain', 92.66, 19.69, 'Advanced'),
    ('Sri Lanka', 73.45, 36.52, 'Emerging & developing'),
    ('Sudan', 123.95, 15.28, 'Emerging & developing'),
    ('Sweden', 40.55, 23.55, 'Advanced'),
    ('Switzerland', 40.68, 26.92, 'Advanced'),
    ('São Tomé and Príncipe', 89.04, 16.67, 'Emerging & developing'),
    ('Tajikistan', 37.5, 31.55, 'Emerging & developing'),
    ('Tanzania', 35.69, 35.21, 'Emerging & developing'),
    ('Thailand', 41.54, 24.7, 'Emerging & developing'),
    ('Timor-Leste', 3.51, 43.32, 'Emerging & developing'),
    ('Togo', 47.31, 19.78, 'Emerging & developing'),
    ('Tonga', 48.54, 27.7, 'Emerging & developing'),
    ('Trinidad and Tobago', 44.57, 21.62, 'Emerging & developing'),
    ('Tunisia', 54.6, 23.1, 'Emerging & developing'),
    ('Türkiye, Republic of', 30.15, 30.29, 'Emerging & developing'),
    ('Uganda', 26.87, 26.26, 'Emerging & developing'),
    ('Ukraine', 56.13, 17.94, 'Emerging & developing'),
    ('United Arab Emirates', 18.96, 22.79, 'Emerging & developing'),
    ('United Kingdom', 84.33, 17.93, 'Advanced'),
    ('United States', 104.5, 20.56, 'Advanced'),
    ('Uruguay', 52.06, 18.89, 'Emerging & developing'),
    ('Uzbekistan', 10.0, 27.54, 'Emerging & developing'),
    ('Vanuatu', 28.52, 25.26, 'Emerging & developing'),
    ('Venezuela', 110.2, 12.12, 'Emerging & developing'),
    ('West Bank and Gaza', 31.05, 23.43, 'Emerging & developing'),
    ('Zambia', 49.86, 36.2, 'Emerging & developing'),
    ('Zimbabwe', 35.11, 12.02, 'Emerging & developing'),
]
 
df = pd.DataFrame(data, columns=["country", "debt", "inv", "group"])
 
# ---- EO theme ----
styles = EcoStyles()
styles.register_and_enable_theme()          # match your usual call / theme name
 
points = (
    alt.Chart(df)
    .mark_point(filled=True, size=45, opacity=0.6)
    .encode(
        x=alt.X("debt:Q",
                title="Gross government debt (% of GDP), 2010-2019 avg",
                scale=alt.Scale(domain=[0, 210]),
                axis=alt.Axis(grid=False, tickCount=6)),
        y=alt.Y("inv:Q",
                title="Investment (% of GDP), 2010-2019 avg",
                scale=alt.Scale(domain=[0, 60]),
                axis=alt.Axis(grid=False, tickCount=6)),
        color=alt.Color("group:N",
                scale=alt.Scale(domain=["Advanced", "Emerging & developing"],
                                range=["#E6224B", "#36B7B4"]),
                legend=alt.Legend(orient="none", legendX=400, legendY=0,
                                  direction="vertical", title=None)),
        tooltip=[alt.Tooltip("country:N", title="Country"),
                 alt.Tooltip("debt:Q", title="Debt % GDP", format=".1f"),
                 alt.Tooltip("inv:Q", title="Investment % GDP", format=".1f")],
    )
)
 
chart = points.properties(
    width=600, height=440,
    title=alt.Title(
        "Higher debt, weaker investment - but only faintly",
        subtitle="Gross government debt vs total investment, 2010-2019 averages, by economy",
    ),
)
 
styles.save(chart, name="debt_investment_scatter",
            source="IMF World Economic Outlook; World Bank", svg=True)
chart
# Out:
# alt.Chart(...)
