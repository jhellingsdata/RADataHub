# %%
import pandas as pd

# %%
df = pd.read_csv('unemp_nuts2_euro.csv')
df
# Out:
#         id        date  value         country                      name iso3
# 0     AT11  2012-01-01    4.6         Austria                Burgenland  AUT
# 1     AT11  2013-01-01    4.3         Austria                Burgenland  AUT
# 2     AT11  2014-01-01    4.8         Austria                Burgenland  AUT
# 3     AT11  2015-01-01    5.2         Austria                Burgenland  AUT
# 4     AT11  2016-01-01    5.7         Austria                Burgenland  AUT
# ...    ...         ...    ...             ...                       ...  ...
# 3768  UKN0  2015-01-01    6.1  United Kingdom  Northern Ireland (UK) ()  GBR
# 3769  UKN0  2016-01-01    5.7  United Kingdom  Northern Ireland (UK) ()  GBR
# 3770  UKN0  2017-01-01    4.5  United Kingdom  Northern Ireland (UK) ()  GBR
# 3771  UKN0  2018-01-01    3.6  United Kingdom  Northern Ireland (UK) ()  GBR
# 3772  UKN0  2019-01-01    2.7  United Kingdom  Northern Ireland (UK) ()  GBR
#
# [3773 rows x 6 columns]

# %%
wide_df = df.pivot(index=["id", "country", "name", "iso3"], columns="date", values="value").reset_index()

wide_df
# Out:
# date    id         country                      name iso3  2012-01-01  \
# 0     AT11         Austria                Burgenland  AUT         4.6
# 1     AT12         Austria          Niederösterreich  AUT         4.6
# 2     AT13         Austria                      Wien  AUT         8.9
# 3     AT21         Austria                   Kärnten  AUT         5.0
# 4     AT22         Austria                Steiermark  AUT         4.0
# ..     ...             ...                       ...  ...         ...
# 334   UKM6  United Kingdom  Highlands and Islands ()  GBR         8.1
# 335   UKM7  United Kingdom       Eastern Scotland ()  GBR         NaN
# 336   UKM8  United Kingdom  West Central Scotland ()  GBR         NaN
# 337   UKM9  United Kingdom      Southern Scotland ()  GBR         NaN
# 338   UKN0  United Kingdom  Northern Ireland (UK) ()  GBR         7.4
#
# date  2013-01-01  2014-01-01  2015-01-01  2016-01-01  2017-01-01  2018-01-01  \
# ...

# %%
wide_df.to_csv('unemp_nuts2_euro_wide.csv', index=False)
