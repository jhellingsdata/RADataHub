# %%
import pandas as pd

# %%
world_url = "https://raw.githubusercontent.com/lukes/ISO-3166-Countries-with-Regional-Codes/refs/heads/master/all/all.csv"

world = pd.read_csv(world_url)

# %%
fips_url = 'https://raw.githubusercontent.com/kjhealy/fips-codes/refs/heads/master/state_and_county_fips_master.csv'

fips = pd.read_csv(fips_url)

# %%
fips
# Out:
#        fips               name state
# 0         0      UNITED STATES   NaN
# 1      1000            ALABAMA   NaN
# 2      1001     Autauga County    AL
# 3      1003     Baldwin County    AL
# 4      1005     Barbour County    AL
# ...     ...                ...   ...
# 3190  56037  Sweetwater County    WY
# 3191  56039       Teton County    WY
# 3192  56041       Uinta County    WY
# 3193  56043    Washakie County    WY
# 3194  56045      Weston County    WY
#
# [3195 rows x 3 columns]

# %%
# find only the rows in fips where the value in 'name' is all caps
fips[fips['name'].str.isupper()]
# Out:
#        fips                  name state
# 0         0         UNITED STATES   NaN
# 1      1000               ALABAMA   NaN
# 69     2000                ALASKA   NaN
# 99     4000               ARIZONA   NaN
# 115    5000              ARKANSAS   NaN
# 191    6000            CALIFORNIA   NaN
# 250    8000              COLORADO   NaN
# 315    9000           CONNECTICUT   NaN
# 324   10000              DELAWARE   NaN
# 328   11000  DISTRICT OF COLUMBIA   NaN
# 330   12000               FLORIDA   NaN
# 398   13000               GEORGIA   NaN
# 558   15000                HAWAII   NaN
# 564   16000                 IDAHO   NaN
# 609   17000              ILLINOIS   NaN
# 712   18000               INDIANA   NaN
# 805   19000                  IOWA   NaN
# 905   20000                KANSAS   NaN
# 1011  21000              KENTUCKY   NaN
# 1132  22000             LOUISIANA   NaN
# 1197  23000                 MAINE   NaN
# 1214  24000              MARYLAND   NaN
# ...

# %%
states = fips[fips['name'].str.isupper()]
states
# Out:
#        fips                  name state
# 0         0         UNITED STATES   NaN
# 1      1000               ALABAMA   NaN
# 69     2000                ALASKA   NaN
# 99     4000               ARIZONA   NaN
# 115    5000              ARKANSAS   NaN
# 191    6000            CALIFORNIA   NaN
# 250    8000              COLORADO   NaN
# 315    9000           CONNECTICUT   NaN
# 324   10000              DELAWARE   NaN
# 328   11000  DISTRICT OF COLUMBIA   NaN
# 330   12000               FLORIDA   NaN
# 398   13000               GEORGIA   NaN
# 558   15000                HAWAII   NaN
# 564   16000                 IDAHO   NaN
# 609   17000              ILLINOIS   NaN
# 712   18000               INDIANA   NaN
# 805   19000                  IOWA   NaN
# 905   20000                KANSAS   NaN
# 1011  21000              KENTUCKY   NaN
# 1132  22000             LOUISIANA   NaN
# 1197  23000                 MAINE   NaN
# 1214  24000              MARYLAND   NaN
# ...

# %%
# drop the first row of states
states = states.iloc[1:]

# %%
# drop the last three digits of every number in the 'fips' column
states['fips'] = states['fips'].astype(str).str[:-3].astype(int)
states
# Out:
# /var/folders/jd/5wy1jytx2pg8j4jr12tl0k_m0000gn/T/ipykernel_62601/2464996137.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   states['fips'] = states['fips'].astype(str).str[:-3].astype(int)
#       fips                  name state
# 1        1               ALABAMA   NaN
# 69       2                ALASKA   NaN
# 99       4               ARIZONA   NaN
# 115      5              ARKANSAS   NaN
# 191      6            CALIFORNIA   NaN
# 250      8              COLORADO   NaN
# 315      9           CONNECTICUT   NaN
# 324     10              DELAWARE   NaN
# 328     11  DISTRICT OF COLUMBIA   NaN
# 330     12               FLORIDA   NaN
# 398     13               GEORGIA   NaN
# 558     15                HAWAII   NaN
# ...

# %%
states.drop(
    columns=''
)

# %%
# read in the topojson files
import json
