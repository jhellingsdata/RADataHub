# %%
import pandas as pd
import requests
import altair as alt
import eco_style

alt.themes.enable('light')
# Out:
# /Users/hannah/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/hannah/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (
# ThemeRegistry.enable('light')

# %%
dfr = pd.read_csv('grp_arctic_russia.csv')
dfr
# Out:
#                          Region  GRP 2012 (1b000 mill. Rubles)  Per cent 2012  \
# 0               Murmansk Region                            284            4.8
# 1                       Karelia                            161            2.7
# 2            Arkhangelsk Region                            472            7.9
# 3                 Komi Republic                            479            8.0
# 4  Yamal-Nenets Autonomous Area                           1191           20.0
# 5                 Khanty-Mansii                           2704           45.4
# 6   Republic of Sakha (Yakutia)                            541            9.1
# 7                Magadan Region                             78            1.3
# 8      Chukotka Autonomous Area                             46            0.8
# 9                         Total                           5956          100.0
#
#    GRP 2015 (1b000 mill. Rubles)  Per cent 2015  \
# 0                            402            5.2
# ...

# %%
dfa = pd.read_csv('arctic_indicators_data.csv')
dfa
# Out:
#                   Regions  Population  Population Growth Rate 2012-2018 (%)  \
# 0                  Alaska      735139                                   0.1
# 1   Northwest Territories       44956                                   0.5
# 2                 Nunavut       38139                                   1.6
# 3                   Yukon       40612                                   1.9
# 4           Faroe Islands       50475                                   0.8
# 5                 Lapland      178522                                  -0.4
# 6   Northern Ostrobothnia      412161                                   0.3
# 7                  Kainuu       73061                                  -1.0
# 8               Greenland       55877                                  -0.3
# 9                 Iceland      348450                                   1.4
# 10               Finnmark       76167                                   0.5
# ...
