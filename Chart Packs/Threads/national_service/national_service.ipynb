# %%
import pandas as pd
import numpy as np
import eco_style
import altair as alt
import pycountry
import requests

alt.themes.enable('light')
# Out:
# ThemeRegistry.enable('light')

# %% [markdown]
# # Where has national service

# %%
# let's fetch from wikipedia, filter for Europe and manually verify
dfs = pd.read_html("https://en.wikipedia.org/wiki/Conscription")

# %%
df = dfs[2].copy()
# remove all (bracketed) bits in the Country column
df['Country'] = df['Country'].str.replace(r'\[.*?\]|\(.*?\)', '', regex=True)

# get the iso3s and numeric ids
def get_country_iso3(country):
    try:
        result = pycountry.countries.search_fuzzy(country)
        iso3 = result[0].alpha_3
        numeric = result[0].numeric
        iso2 = result[0].alpha_2
        return iso3, numeric, iso2
    except LookupError:
        print(f"Could not find {country}")
        return None, None, None
    
df['iso3_numeric'] = df['Country'].apply(get_country_iso3)
df['iso3'] = df['iso3_numeric'].apply(lambda x: x[0])
df['numeric'] = df['iso3_numeric'].apply(lambda x: x[1])
df['id'] = df['iso3_numeric'].apply(lambda x: x[2])

# %%
req = requests.get("https://raw.githubusercontent.com/jhellingsdata/RADataHub/main/e4e/ch8_Trends/data/chart8_x_europe.topojson")
geo = req.json()
eur_countries = geo['objects']['europe']['geometries']
eur_iso2s = [country['id'] for country in eur_countries]

# %%
# filter the df for Europe
df = df[df['id'].isin(eur_iso2s)]
eur_df = df.copy()

# %%
df.columns
# Out:
# Index(['Country', 'Conscription[112]', 'Conscription sex', 'iso3_numeric',
#        'iso3', 'numeric', 'id'],
#       dtype='object')

# %%
df = eur_df.copy().query("iso3 != 'ISR'")
df = df.rename(columns={'Conscription[112]': 'Conscription'})
# all the Conscriptions start with No or Yes
df['value'] = df['Conscription'].apply(lambda x: x.split()[0])
df['value'] = df['value'].apply(lambda x: 'Yes' in x)
df = df[['Country', 'value', 'iso3', 'numeric', 'id', 'Conscription']]

manual_additions = [
    {
        "Country": "Belarus",
        "value": True,
        "iso3": "BLR",
        "numeric": 112,
        "id": "BY",
    },
    {
        "Country" : "Montenegro",
        "value": False,
        "iso3": "MNE",
        "numeric": 499,
        "id": "ME",
    }
]


df = pd.concat([df, pd.DataFrame(manual_additions)], ignore_index=True)

df[['iso3', 'id', 'value']].to_csv("conscription.csv", index=False)

# %%
len(df.query("value == True"))
# Out:
# 18

# %%
df
# Out:
#                    Country  value iso3 numeric  id  \
# 0                  Albania  False  ALB     008  AL
# 1                  Armenia   True  ARM     051  AM
# 2                  Austria   True  AUT     040  AT
# 3               Azerbaijan   True  AZE     031  AZ
# 4                  Belgium  False  BEL     056  BE
# 5   Bosnia and Herzegovina  False  BIH     070  BA
# 6                 Bulgaria  False  BGR     100  BG
# 7                  Croatia  False  HRV     191  HR
# 8                  Cyprus    True  CYP     196  CY
# 9           Czech Republic  False  CZE     203  CZ
# 10                Denmark    True  DNK     208  DK
# 11                 Estonia   True  EST     233  EE
# 12                Finland    True  FIN     246  FI
# 13                  France  False  FRA     250  FR
# 14                Germany   False  DEU     276  DE
# 15                 Greece    True  GRC     300  GR
# 16                 Hungary  False  HUN     348  HU
# 17                 Ireland  False  IRL     372  IE
# 18                   Italy  False  ITA     380  IT
# 19                  Latvia   True  LVA     428  LV
# 20               Lithuania   True  LTU     440  LT
# 21              Luxembourg  False  LUX     442  LU
# 22                   Malta  False  MLT     470  MT
# 23                 Moldova   True  MDA     498  MD
# 24            Netherlands   False  NLD     528  NL
# 25         North Macedonia  False  MKD     807  MK
# 26                  Norway   True  NOR     578  NO
# 27                  Poland  False  POL     616  PL
# 28                Portugal  False  PRT     620  PT
# 29                 Romania  False  ROU     642  RO
# 30                 Russia    True  RUS     643  RU
# 31                 Serbia   False  SRB     688  RS
# 32                Slovakia  False  SVK     703  SK
# 33                Slovenia  False  SVN     705  SI
# 34                   Spain  False  ESP     724  ES
# 35                  Sweden   True  SWE     752  SE
# 36             Switzerland   True  CHE     756  CH
# 37                 Turkey    True  TUR     792  TR
# 38                 Ukraine   True  UKR     804  UA
# 39         United Kingdom   False  GBR     826  GB
# 40                 Belarus   True  BLR     112  BY
# 41              Montenegro  False  MNE     499  ME
#
#                                          Conscription
# 0                         No (abolished in 2010)[113]
# 1                                                 Yes
# 2            Yes (alternative service available)[116]
# 3                                                 Yes
# 4   No (suspended in 1992; service not required of...
# 5               No (abolished on 1 January 2006)[120]
# 6        No (abolished by law on 1 January 2008)[123]
# 7                  No (abolished by law in 2008)[128]
# 8                 Yes (alternative service available)
# 9                         No (abolished in 2005)[129]
# 10  Yes (alternative service available).[130][131]...
# 11                Yes (alternative service available)
# 12                Yes (alternative service available)
# 13  No (suspended during peacetime in 2001).[134] ...
# 14  No (suspended during peacetime by the federal ...
# 15                Yes (alternative service available)
# 16  No (peacetime conscription abolished in 2004)[...
# 17                                                 No
# 18       No (suspended during peacetime in 2005)[138]
# 19  Yes[143] (abolished in 2007, reintroduced on J...
# 20  Yes[146] About 3,000–4,000 conscripts each yea...
# 21                                                 No
# 22                                                 No
# 23                                           Yes[150]
# 24  No. Active conscription suspended in 1997 (exc...
# 25                        No (abolished in 2006)[157]
# 26  Yes by law, but in practice people are not for...
# 27  No. Ended in 2009, but selective registration ...
# 28  No. Peacetime conscription abolished in 2004, ...
# 29                         No (ended in January 2007)
# 30                Yes (alternative service available)
# 31                  No (abolished on January 1, 2011)
# 32             No (abolished on January 1, 2006)[167]
# 33                                            No[168]
# 34     No (abolished by law on 31 December 2001)[171]
# 35  Yes. Abolished in 2010 but reintroduced in 201...
# 36           Yes (alternative service available)[173]
# 37                                           Yes[178]
# 38  Yes (abolished in 2013, reinstated in 2014 due...
# 39  No. Required from 1916 until 1920 and from 193...
# 40                                                NaN
# 41                                                NaN

# %% [markdown]
# # Europe Timeline

# %%
df = pd.read_csv("eur_conscription.csv")
df = df[['iso3', 'started_year', 'ended_year']]
df.columns = ['iso3', 'start', 'end']
df = df.query('end > start')

exclude = [
    "FRA" # France suspended conscription in 1997 but only officially ended it in 2001 but let's exclude it because it's a bit of a mess and lots of countries have suspended it

]

def get_name(x):
    if x == 'RUS':
        return "Russia"
    if x == 'TUR':
        return "Türkiye"
    try:
        res = pycountry.countries.get(alpha_3=x)
        # if it has a common_name, use that
        try:
            return res.common_name
        except AttributeError:
            return res.name
    except LookupError:
        return None


df['name'] = df['iso3'].apply(lambda x: get_name(x))

df['start'] = pd.to_datetime(df['start'], format='%Y')
df['end'] = pd.to_datetime(df['end'], format='%Y')

df = df.sort_values('end')
df['rank'] = np.arange(len(df))

df['start_label'] = 'Start'
df['end_label'] = 'End'

base = alt.Chart(df).encode(
    y=alt.X('name:N', sort="-x", 
            axis=alt.Axis(domain=False,
                          labelFontSize=13,
                           labelColor="#1d1d1d"),
            title=None),
    x=alt.X('start:T',
            axis=alt.Axis(
                labelFontSize=13,
            ),
            scale=alt.Scale(zero=False,
                            domain=(pd.Timestamp('2000'),
                                    pd.Timestamp('2024-12-31')),
                                    clamp=True),
                            ),

    x2='end:T'

)

rules = base.mark_rule()

# add filled start and end points
start_points = base.transform_filter(
    'year(datum.start) >1999').mark_circle(
        size=75,
        opacity=1,
        color="#36b7b4")
end_points = base.transform_filter('year(datum.end) <2025').transform_calculate(
    start='datum.end' # this is a hack - if we use the end in the encoding, it'll break the ordering
).mark_circle(color="#e6224b", size=75, opacity=1)

# text on Sweden to annotate the start and end points
swe_start_text = base.transform_filter('datum.iso3 == "SWE" && year(datum.start) > 2005').mark_text(
    align='right',
    baseline='middle',
    dx=-8,
    dy=0,
    fontSize=13,
    color="#36b7b4",
    text='Start'
).encode(
    text=alt.Text('start_label')
)

swe_end_text = base.transform_filter('datum.iso3 == "SWE" && year(datum.end) < 2020').transform_calculate(
    start='datum.end' # same hack as above
).mark_text(
        align='left',
    baseline='middle',
    dx=8,
    dy=0,
    fontSize=13,
    color="#e6224b",
    text='End'
).encode(
    text=alt.Text('end_label')
)
chart = rules + start_points+end_points + swe_start_text + swe_end_text

chart = chart.properties(
    height=600,
    width=400,
    title = alt.TitleParams(
        text="National Service in the 21st Century",
        subtitle=["European countries with national service since 2000", "Various sources", ""],
        fontSize=16,
        subtitleFontSize=12,
        anchor="start",
        dx=140
    )
)

chart
# Out:
# /Users/finn/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/finn/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/finn/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.LayerChart(...)

# %%
df
# Out:
#    iso3      start        end                    name  rank start_label  \
# 31  ESP 1999-01-01 2001-01-01                   Spain     0       Start
# 13  FRA 1999-01-01 2001-01-01                  France     1       Start
# 26  PRT 1999-01-01 2004-01-01                Portugal     2       Start
# 16  HUN 1999-01-01 2004-01-01                 Hungary     3       Start
# 9   CZE 1999-01-01 2005-01-01                 Czechia     4       Start
# 17  ITA 1999-01-01 2005-01-01                   Italy     5       Start
# 39  MNE 1999-01-01 2006-01-01              Montenegro     6       Start
# 30  SVK 1999-01-01 2006-01-01                Slovakia     7       Start
# 5   BIH 1999-01-01 2006-01-01  Bosnia and Herzegovina     8       Start
# 23  MKD 1999-01-01 2006-01-01         North Macedonia     9       Start
# 27  ROU 1999-01-01 2007-01-01                 Romania    10       Start
# 18  LVA 1999-01-01 2007-01-01                  Latvia    11       Start
# 6   BGR 1999-01-01 2008-01-01                Bulgaria    12       Start
# 7   HRV 1999-01-01 2008-01-01                 Croatia    13       Start
# 25  POL 1999-01-01 2009-01-01                  Poland    14       Start
# 32  SWE 1999-01-01 2010-01-01                  Sweden    15       Start
# 0   ALB 1999-01-01 2010-01-01                 Albania    16       Start
# 14  DEU 1999-01-01 2011-01-01                 Germany    17       Start
# 29  SRB 1999-01-01 2011-01-01                  Serbia    18       Start
# 36  UKR 1999-01-01 2013-01-01                 Ukraine    19       Start
# 20  LTU 1999-01-01 2025-01-01               Lithuania    20       Start
# 37  UKR 2014-01-01 2025-01-01                 Ukraine    21       Start
# 35  TUR 1999-01-01 2025-01-01                  Turkey    22       Start
# 34  CHE 1999-01-01 2025-01-01             Switzerland    23       Start
# 33  SWE 2017-01-01 2025-01-01                  Sweden    24       Start
# 1   ARM 1999-01-01 2025-01-01                 Armenia    25       Start
# 2   AUT 1999-01-01 2025-01-01                 Austria    26       Start
# 38  BLR 1999-01-01 2025-01-01                 Belarus    27       Start
# 3   AZE 1999-01-01 2025-01-01              Azerbaijan    28       Start
# 28  RUS 1999-01-01 2025-01-01                  Russia    29       Start
# 8   CYP 1999-01-01 2025-01-01                  Cyprus    30       Start
# 10  DNK 1999-01-01 2025-01-01                 Denmark    31       Start
# 11  EST 1999-01-01 2025-01-01                 Estonia    32       Start
# 24  NOR 1999-01-01 2025-01-01                  Norway    33       Start
# 12  FIN 1999-01-01 2025-01-01                 Finland    34       Start
# 21  MDA 1999-01-01 2025-01-01                 Moldova    35       Start
# 15  GRC 1999-01-01 2025-01-01                  Greece    36       Start
# 19  LVA 2024-01-01 2025-01-01                  Latvia    37       Start
#
#    end_label
# 31       End
# 13       End
# 26       End
# 16       End
# 9        End
# 17       End
# 39       End
# 30       End
# 5        End
# 23       End
# 27       End
# 18       End
# 6        End
# 7        End
# 25       End
# 32       End
# 0        End
# 14       End
# 29       End
# 36       End
# 20       End
# 37       End
# 35       End
# 34       End
# 33       End
# 1        End
# 2        End
# 38       End
# 3        End
# 28       End
# 8        End
# 10       End
# 11       End
# 24       End
# 12       End
# 21       End
# 15       End
# 19       End

# %%
chart.save("conscription_chart.png", scale_factor=3.0)
# Out:
# /Users/finn/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/finn/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/finn/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# WARN x2 dropped as it is incompatible with "circle".
# WARN x2 dropped as it is incompatible with "circle".
# WARN x2 dropped as it is incompatible with "text".
# WARN x2 dropped as it is incompatible with "text".
# WARN Conflicting scale property "domain" ([{"signal":"{data: datetime(\"2000-01-01T00:00:00\")}"},{"signal":"{data: datetime(\"2024-12-31T00:00:00\")}"}] and [["2000-01-01T00:00:00","2024-12-31T00:00:00"]]). Using the union of the two domains.
# WARN Conflicting scale property "domains" ([{"signal":"{data: datetime(\"2000-01-01T00:00:00\")}"},{"signal":"{data: datetime(\"2024-12-31T00:00:00\")}"},["2000-01-01T00:00:00","2024-12-31T00:00:00"]] and [{"signal":"{data: datetime(\"2000-01-01T00:00:00\")}"},{"signal":"{data: datetime(\"2024-12-31T00:00:00\")}"}]). Using the union of the two domains.
# WARN Conflicting scale property "domains" ([{"signal":"{data: datetime(\"2000-01-01T00:00:00\")}"},{"signal":"{data: datetime(\"2024-12-31T00:00:00\")}"},["2000-01-01T00:00:00","2024-12-31T00:00:00"],{"signal":"{data: datetime(\"2000-01-01T00:00:00\")}"},{"signal":"{data: datetime(\"2024-12-31T00:00:00\")}"}] and [{"signal":"{data: datetime(\"2000-01-01T00:00:00\")}"},{"signal":"{data: datetime(\"2024-12-31T00:00:00\")}"}]). Using the union of the two domains.
# WARN Conflicting scale property "domains" ([{"signal":"{data: datetime(\"2000-01-01T00:00:00\")}"},{"signal":"{data: datetime(\"2024-12-31T00:00:00\")}"},["2000-01-01T00:00:00","2024-12-31T00:00:00"],{"signal":"{data: datetime(\"2000-01-01T00:00:00\")}"},{"signal":"{data: datetime(\"2024-12-31T00:00:00\")}"},{"signal":"{data: datetime(\"2000-01-01T00:00:00\")}"},{"signal":"{data: datetime(\"2024-12-31T00:00:00\")}"}] and [{"signal":"{data: datetime(\"2000-01-01T00:00:00\")}"},{"signal":"{data: datetime(\"2024-12-31T00:00:00\")}"}]). Using the union of the two domains.
# WARN Conflicting scale property "domains" ([{"signal":"{data: datetime(\"2000-01-01T00:00:00\")}"},{"signal":"{data: datetime(\"2024-12-31T00:00:00\")}"},["2000-01-01T00:00:00","2024-12-31T00:00:00"],{"signal":"{data: datetime(\"2000-01-01T00:00:00\")}"},{"signal":"{data: datetime(\"2024-12-31T00:00:00\")}"},{"signal":"{data: datetime(\"2000-01-01T00:00:00\")}"},{"signal":"{data: datetime(\"2024-12-31T00:00:00\")}"},{"signal":"{data: datetime(\"2000-01-01T00:00:00\")}"},{"signal":"{data: datetime(\"2024-12-31T00:00:00\")}"}] and [{"signal":"{data: datetime(\"2000-01-01T00:00:00\")}"},{"signal":"{data: datetime(\"2024-12-31T00:00:00\")}"}]). Using the union of the two domains.
# WARN x-scale's "zero" is dropped as it does not work with time scale.
# WARN x-scale's "zero" is dropped as it does not work with time scale.
# WARN x-scale's "zero" is dropped as it does not work with time scale.
# WARN x-scale's "zero" is dropped as it does not work with time scale.
# WARN x-scale's "zero" is dropped as it does not work with time scale.

# %%
len(df.query("end < 2010"))
# Out:
# 15

# %%
df.query("end > 2010 and end < 2025")
# Out:
#    iso3      start        end     name  rank start_label end_label
# 14  DEU 1999-01-01 2011-01-01  Germany    17       Start       End
# 29  SRB 1999-01-01 2011-01-01   Serbia    18       Start       End
# 36  UKR 1999-01-01 2013-01-01  Ukraine    19       Start       End

# %%
df.query("end < 2010")
# Out:
#    iso3      start        end                    name  rank start_label  \
# 31  ESP 1999-01-01 2001-01-01                   Spain     0       Start
# 13  FRA 1999-01-01 2001-01-01                  France     1       Start
# 26  PRT 1999-01-01 2004-01-01                Portugal     2       Start
# 16  HUN 1999-01-01 2004-01-01                 Hungary     3       Start
# 9   CZE 1999-01-01 2005-01-01                 Czechia     4       Start
# 17  ITA 1999-01-01 2005-01-01                   Italy     5       Start
# 39  MNE 1999-01-01 2006-01-01              Montenegro     6       Start
# 30  SVK 1999-01-01 2006-01-01                Slovakia     7       Start
# 5   BIH 1999-01-01 2006-01-01  Bosnia and Herzegovina     8       Start
# 23  MKD 1999-01-01 2006-01-01         North Macedonia     9       Start
# 27  ROU 1999-01-01 2007-01-01                 Romania    10       Start
# 18  LVA 1999-01-01 2007-01-01                  Latvia    11       Start
# 6   BGR 1999-01-01 2008-01-01                Bulgaria    12       Start
# 7   HRV 1999-01-01 2008-01-01                 Croatia    13       Start
# 25  POL 1999-01-01 2009-01-01                  Poland    14       Start
#
#    end_label
# 31       End
# 13       End
# 26       End
# 16       End
# 9        End
# 17       End
# 39       End
# 30       End
# 5        End
# 23       End
# 27       End
# 18       End
# 6        End
# 7        End
# 25       End

# %%
df
# Out:
#    iso3      start        end                    name  rank start_label  \
# 31  ESP 1999-01-01 2001-01-01                   Spain     0       Start
# 13  FRA 1999-01-01 2001-01-01                  France     1       Start
# 26  PRT 1999-01-01 2004-01-01                Portugal     2       Start
# 16  HUN 1999-01-01 2004-01-01                 Hungary     3       Start
# 9   CZE 1999-01-01 2005-01-01                 Czechia     4       Start
# 17  ITA 1999-01-01 2005-01-01                   Italy     5       Start
# 39  MNE 1999-01-01 2006-01-01              Montenegro     6       Start
# 30  SVK 1999-01-01 2006-01-01                Slovakia     7       Start
# 5   BIH 1999-01-01 2006-01-01  Bosnia and Herzegovina     8       Start
# 23  MKD 1999-01-01 2006-01-01         North Macedonia     9       Start
# 27  ROU 1999-01-01 2007-01-01                 Romania    10       Start
# 18  LVA 1999-01-01 2007-01-01                  Latvia    11       Start
# 6   BGR 1999-01-01 2008-01-01                Bulgaria    12       Start
# 7   HRV 1999-01-01 2008-01-01                 Croatia    13       Start
# 25  POL 1999-01-01 2009-01-01                  Poland    14       Start
# 32  SWE 1999-01-01 2010-01-01                  Sweden    15       Start
# 0   ALB 1999-01-01 2010-01-01                 Albania    16       Start
# 14  DEU 1999-01-01 2011-01-01                 Germany    17       Start
# 29  SRB 1999-01-01 2011-01-01                  Serbia    18       Start
# 36  UKR 1999-01-01 2013-01-01                 Ukraine    19       Start
# 20  LTU 1999-01-01 2025-01-01               Lithuania    20       Start
# 37  UKR 2014-01-01 2025-01-01                 Ukraine    21       Start
# 35  TUR 1999-01-01 2025-01-01                  Turkey    22       Start
# 34  CHE 1999-01-01 2025-01-01             Switzerland    23       Start
# 33  SWE 2017-01-01 2025-01-01                  Sweden    24       Start
# 1   ARM 1999-01-01 2025-01-01                 Armenia    25       Start
# 2   AUT 1999-01-01 2025-01-01                 Austria    26       Start
# 38  BLR 1999-01-01 2025-01-01                 Belarus    27       Start
# 3   AZE 1999-01-01 2025-01-01              Azerbaijan    28       Start
# 28  RUS 1999-01-01 2025-01-01      Russian Federation    29       Start
# 8   CYP 1999-01-01 2025-01-01                  Cyprus    30       Start
# 10  DNK 1999-01-01 2025-01-01                 Denmark    31       Start
# 11  EST 1999-01-01 2025-01-01                 Estonia    32       Start
# 24  NOR 1999-01-01 2025-01-01                  Norway    33       Start
# 12  FIN 1999-01-01 2025-01-01                 Finland    34       Start
# 21  MDA 1999-01-01 2025-01-01                 Moldova    35       Start
# 15  GRC 1999-01-01 2025-01-01                  Greece    36       Start
# 19  LVA 2024-01-01 2025-01-01                  Latvia    37       Start
#
#    end_label
# 31       End
# 13       End
# 26       End
# 16       End
# 9        End
# 17       End
# 39       End
# 30       End
# 5        End
# 23       End
# 27       End
# 18       End
# 6        End
# 7        End
# 25       End
# 32       End
# 0        End
# 14       End
# 29       End
# 36       End
# 20       End
# 37       End
# 35       End
# 34       End
# 33       End
# 1        End
# 2        End
# 38       End
# 3        End
# 28       End
# 8        End
# 10       End
# 11       End
# 24       End
# 12       End
# 21       End
# 15       End
# 19       End

# %% [markdown]
# # NEET Young People by Country

# %%
# Out:
# Could not find OECD - Average
# Could not find Türkiye

# %%
dfs = pd.read_html("oecd_neet.html")
df = dfs[0]

df.columns = [c.replace("▾", "").strip() for c in df.columns]
df = df.melt(id_vars=['Location'], var_name='date', value_name='value')
df = df.rename(columns={'Location': 'country'})

iso3s = {}
for country in df['country'].unique():
    try:
        result = pycountry.countries.search_fuzzy(country)
        iso3 = result[0].alpha_3
        iso3s[country] = iso3
    except LookupError:
        print(f"Could not find {country}")
        iso3s[country] = None

df['iso3'] = df['country'].apply(lambda x: iso3s[x])

df = df.dropna(subset=['value'])
OECD_iso3 = [  "AUS",  "AUT",  "BEL",  "CAN",  "CHL",  "COL",  "CRI",  "CZE",  "DNK",  "EST",  "FIN",  "FRA",  "DEU",  "GRC",  "HUN",  "ISL",  "IRL",  "ISR",  "ITA",  "JPN",  "KOR",  "LVA",  "LTU",  "LUX",  "MEX",  "NLD",  "NZL",  "NOR",  "POL",  "PRT",  "SVK",  "SVN",  "ESP",  "SWE",  "CHE",  "TUR",  "GBR",  "USA"]

df['value'] = df['value']/100

df = df.query('iso3 in @OECD_iso3')
# get the low and high 10pctiles
# corp_df['low'] = corp_df.groupby(by=["Time"])['Value'].transform(lambda x: x.quantile(0.1))
df['low'] = df.groupby(by=["date"])['value'].transform(lambda x: x.quantile(0.1))
df['high'] = df.groupby(by=["date"])['value'].transform(lambda x: x.quantile(0.9))
df['median'] = df.groupby(by=["date"])['value'].transform('median')
df['rank'] = df.groupby(by=["date"])['value'].rank(ascending=False)

df
# Out:
# Could not find OECD - Average
# Could not find Türkiye
#              country  date   value iso3      low     high  median  rank
# 1          Australia  1997  0.0807  AUS  0.02592  0.14696  0.0740   8.0
# 3            Belgium  1997  0.0897  BEL  0.02592  0.14696  0.0740   6.0
# 6             Canada  1997  0.0774  CAN  0.02592  0.14696  0.0740   9.0
# 10           Czechia  1997  0.0500  CZE  0.02592  0.14696  0.0740  14.0
# 11           Denmark  1997  0.0145  DNK  0.02592  0.14696  0.0740  19.0
# ...              ...   ...     ...  ...      ...      ...     ...   ...
# 1138           Spain  2022  0.0748  ESP  0.03302  0.13894  0.0635  12.0
# 1139          Sweden  2022  0.0371  SWE  0.03302  0.13894  0.0635  28.0
# 1140     Switzerland  2022  0.2036  CHE  0.03302  0.13894  0.0635   3.0
# 1142  United Kingdom  2022  0.0744  GBR  0.03302  0.13894  0.0635  13.0
# 1143   United States  2022  0.0871  USA  0.03302  0.13894  0.0635   8.0
#
# [773 rows x 8 columns]

# %%
#      "category" : ["#36B7B4","#E6224B","#F4C245","#0063AF","#00A767","#179FDB","#EB5C2E"],
highlight_countries = {
    "USA": "#36B7B4",
    "GBR": "#E6224B",
    "FRA": "#F4C245",
    "DEU": "#0063AF",
    "other": "rgba(0,0,0,0.1)"
}

df['color'] = df['iso3'].apply(lambda x: highlight_countries.get(x, highlight_countries['other']))
# add a label to the latest value for each country
df['label'] = df.apply(lambda x: x['country'] if x['date'] == '2022' and x['iso3'] in highlight_countries else '', axis=1)
df['highlighted'] = df['iso3'].apply(lambda x: x in highlight_countries)

df = df.sort_values('date')
df['date'] = pd.to_numeric(df['date'])

df = df.query('iso3 in @highlight_countries.keys() and date > 1999') 

df['date'] = pd.to_datetime(df['date'], format='%Y')

base = alt.Chart(df).encode(
    x=alt.X('date:T', axis=alt.Axis(), scale=alt.Scale()),
    y=alt.Y('value:Q', axis=alt.Axis(title=None, format="%")),
    color=alt.Color('color:N', scale=None),
    detail='country:N',
)

lines = base.mark_line().encode(
    size=alt.condition(alt.datum.iso3 == 'GBR', alt.value(2), alt.value(1))
)

end_labels = base.transform_filter('datum.highlighted').mark_text(
    align='left',
    baseline='middle',
    dx=5,
    dy=0,
    fontSize=alt.expr("datum.iso3 == 'GBR' ? 13 : 11"),
).encode(
    text=alt.Text('label'),
)

# shade the end area
shade = base.mark_area(opacity=1, color="rgba(24, 42, 56, 1)").encode(
    x=alt.X('date:T'),
    y=alt.Y('low:Q'),
    y2=alt.Y2('high:Q'),
    color=alt.value("rgb(232, 232, 232)")
)

chart = shade + lines + end_labels

chart = chart.properties(
    width=400,
    height=300,
    title=alt.TitleParams(
        text="NEET Rates in OECD Countries",
        subtitle=["15-19 year-olds not in education, employment or training", "OECD coutries, 10th-90th percentiles shaded", ""],
        anchor="start",
        fontSize=16,
        color="#808080",
        subtitleColor="#676A86",
        subtitleFontSize=12
    )
)

chart.save("neet_chart.png", scale_factor=3.0)
chart
# Out:
# /Users/finn/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/finn/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/finn/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/finn/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/finn/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/finn/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.LayerChart(...)

# %%
df
# Out:
#              country       date   value iso3      low     high    color  \
# 175    United States 2000-01-01  0.0790  USA  0.02811  0.12750  #36B7B4
# 174   United Kingdom 2000-01-01  0.0804  GBR  0.02811  0.12750  #E6224B
# 147          Germany 2000-01-01  0.0571  DEU  0.02811  0.12750  #0063AF
# 146           France 2000-01-01  0.0699  FRA  0.02811  0.12750  #F4C245
# 218   United Kingdom 2001-01-01  0.0816  GBR  0.03797  0.12144  #E6224B
# ...              ...        ...     ...  ...      ...      ...      ...
# 1071         Germany 2021-01-01  0.0519  DEU  0.03913  0.12469  #0063AF
# 1142  United Kingdom 2022-01-01  0.0744  GBR  0.03302  0.13894  #E6224B
# 1114          France 2022-01-01  0.0635  FRA  0.03302  0.13894  #F4C245
# 1115         Germany 2022-01-01  0.0464  DEU  0.03302  0.13894  #0063AF
# 1143   United States 2022-01-01  0.0871  USA  0.03302  0.13894  #36B7B4
#
#                label  highlighted
# 175                          True
# 174                          True
# 147                          True
# 146                          True
# 218                          True
# ...              ...          ...
# 1071                         True
# 1142  United Kingdom         True
# 1114          France         True
# 1115         Germany         True
# 1143   United States         True
#
# [91 rows x 9 columns]

# %%
df[df.iso3.isin(['GBR', 'USA', 'FRA', 'DEU'])].drop_duplicates(subset=['country'], keep='first')
# Out:
#             country  date  value iso3    color label  highlighted    low  \
# 43    United States  1997   7.07  USA  #36B7B4               True  2.592
# 14           France  1997   6.80  FRA  #F4C245               True  2.592
# 15          Germany  1997   4.99  DEU  #0063AF               True  2.592
# 174  United Kingdom  2000   8.04  GBR  #E6224B               True  2.811
#
#        high
# 43   14.696
# 14   14.696
# 15   14.696
# 174  12.750

# %%
pycountry.countries.get(alpha_3="MDA").common_name
# Out:
# 'Moldova'

# %%
df
# Out:
#    iso3      start        end
# 31  ESP 1999-01-01 2001-01-01
# 26  PRT 1999-01-01 2004-01-01
# 16  HUN 1999-01-01 2004-01-01
# 9   CZE 1999-01-01 2005-01-01
# 17  ITA 1999-01-01 2005-01-01
# 30  SVK 1999-01-01 2006-01-01
# 5   BIH 1999-01-01 2006-01-01
# 23  MKD 1999-01-01 2006-01-01
# 18  LVA 1999-01-01 2007-01-01
# 27  ROU 1999-01-01 2007-01-01
# 6   BGR 1999-01-01 2008-01-01
# 7   HRV 1999-01-01 2008-01-01
# 25  POL 1999-01-01 2009-01-01
# 0   ALB 1999-01-01 2010-01-01
# 29  SRB 1999-01-01 2011-01-01
# 14  DEU 1999-01-01 2011-01-01
# 35  UKR 1999-01-01 2013-01-01
# 32  SWE 2010-01-01 2017-01-01
# 13  FRA 2001-01-01 2021-01-01
# 15  GRC 1999-01-01 2025-01-01
# 34  TUR 1999-01-01 2025-01-01
# 33  CHE 1999-01-01 2025-01-01
# 1   ARM 1999-01-01 2025-01-01
# 2   AUT 1999-01-01 2025-01-01
# 28  RUS 1999-01-01 2025-01-01
# 8   CYP 1999-01-01 2025-01-01
# 10  DNK 1999-01-01 2025-01-01
# 24  NOR 1999-01-01 2025-01-01
# 11  EST 1999-01-01 2025-01-01
# 21  MDA 1999-01-01 2025-01-01
# 20  LTU 1999-01-01 2025-01-01
# 19  LVA 2024-01-01 2025-01-01
# 12  FIN 1999-01-01 2025-01-01
# 3   AZE 1999-01-01 2025-01-01
# 36  UKR 2014-01-01 2025-01-01

# %%
base.mark_rule()
# Out:
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/altair/vegalite/v5/api.py:2520, in Chart.to_dict(self, *args, **kwargs)
#    2518     copy.data = core.InlineData(values=[{}])
#    2519     return super(Chart, copy).to_dict(*args, **kwargs)
# -> 2520 return super().to_dict(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/altair/vegalite/v5/api.py:850, in TopLevelMixin.to_dict(self, *args, **kwargs)
#     845 kwargs["context"] = context
#     847 # TopLevelMixin instance does not necessarily have to_dict defined
#     848 # but due to how Altair is set up this should hold.
#     849 # Too complex to type hint right now
# --> 850 dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)  # type: ignore[misc]
#     852 # TODO: following entries are added after validation. Should they be validated?
#     853 if is_top_level:
#     854     # since this is top-level we add $schema if it's missing
#
# File ~/anaconda3/lib/python3.11/site-packages/altair/utils/schemapi.py:814, in SchemaBase.to_dict(self, validate, ignore, context)
#     807         self.validate(result)
#     808     except jsonschema.ValidationError as err:
#     809         # We do not raise `from err` as else the resulting
#     810         # traceback is very long as it contains part
#     811         # of the Vega-Lite schema. It would also first
#     812         # show the less helpful ValidationError instead of
#     813         # the more user friendly SchemaValidationError
# --> 814         raise SchemaValidationError(self, err) from None
#     815 return result
#
# SchemaValidationError: `Data` has no parameter named 'arcs'
#
# Existing parameter names are:
# args
#
# See the help for `Data` to read the full description of these parameters
# alt.Chart(...)

# %%
rules = base.mark_rule()

chart = rules

chart

# %%
base.mark_rule()
# Out:
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/altair/vegalite/v5/api.py:2520, in Chart.to_dict(self, *args, **kwargs)
#    2518     copy.data = core.InlineData(values=[{}])
#    2519     return super(Chart, copy).to_dict(*args, **kwargs)
# -> 2520 return super().to_dict(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/altair/vegalite/v5/api.py:850, in TopLevelMixin.to_dict(self, *args, **kwargs)
#     845 kwargs["context"] = context
#     847 # TopLevelMixin instance does not necessarily have to_dict defined
#     848 # but due to how Altair is set up this should hold.
#     849 # Too complex to type hint right now
# --> 850 dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)  # type: ignore[misc]
#     852 # TODO: following entries are added after validation. Should they be validated?
#     853 if is_top_level:
#     854     # since this is top-level we add $schema if it's missing
#
# File ~/anaconda3/lib/python3.11/site-packages/altair/utils/schemapi.py:814, in SchemaBase.to_dict(self, validate, ignore, context)
#     807         self.validate(result)
#     808     except jsonschema.ValidationError as err:
#     809         # We do not raise `from err` as else the resulting
#     810         # traceback is very long as it contains part
#     811         # of the Vega-Lite schema. It would also first
#     812         # show the less helpful ValidationError instead of
#     813         # the more user friendly SchemaValidationError
# --> 814         raise SchemaValidationError(self, err) from None
#     815 return result
#
# SchemaValidationError: `Data` has no parameter named 'arcs'
#
# Existing parameter names are:
# args
#
# See the help for `Data` to read the full description of these parameters
# alt.Chart(...)

# %%
df
# Out:
#                    Country  value iso3 numeric  id  \
# 1                  Albania  False  ALB     008  AL
# 5                  Armenia   True  ARM     051  AM
# 7                  Austria   True  AUT     040  AT
# 8               Azerbaijan   True  AZE     031  AZ
# 12                 Belgium  False  BEL     056  BE
# 16  Bosnia and Herzegovina  False  BIH     070  BA
# 18                Bulgaria  False  BGR     100  BG
# 23                 Croatia  False  HRV     191  HR
# 25                 Cyprus    True  CYP     196  CY
# 26          Czech Republic  False  CZE     203  CZ
# 27                Denmark    True  DNK     208  DK
# 33                 Estonia   True  EST     233  EE
# 35                Finland    True  FIN     246  FI
# 36                  France  False  FRA     250  FR
# 38                Germany   False  DEU     276  DE
# 39                 Greece    True  GRC     300  GR
# 40                 Hungary  False  HUN     348  HU
# 43                 Ireland  False  IRL     372  IE
# 47                   Italy  False  ITA     380  IT
# 52                  Latvia   True  LVA     428  LV
# 55               Lithuania   True  LTU     440  LT
# 56              Luxembourg  False  LUX     442  LU
# 59                   Malta  False  MLT     470  MT
# 61                 Moldova   True  MDA     498  MD
# 65            Netherlands   False  NLD     528  NL
# 69         North Macedonia  False  MKD     807  MK
# 70                  Norway   True  NOR     578  NO
# 73                  Poland  False  POL     616  PL
# 74                Portugal  False  PRT     620  PT
# 76                 Romania  False  ROU     642  RO
# 77                 Russia    True  RUS     643  RU
# 80                 Serbia   False  SRB     688  RS
# 83                Slovakia  False  SVK     703  SK
# 84                Slovenia  False  SVN     705  SI
# 87                   Spain  False  ESP     724  ES
# 88                  Sweden   True  SWE     752  SE
# 89             Switzerland   True  CHE     756  CH
# 96                 Turkey    True  TUR     792  TR
# 98                 Ukraine   True  UKR     804  UA
# 99         United Kingdom   False  GBR     826  GB
#
#                                          Conscription
# 1                         No (abolished in 2010)[113]
# 5                                                 Yes
# 7            Yes (alternative service available)[116]
# 8                                                 Yes
# 12  No (suspended in 1992; service not required of...
# 16              No (abolished on 1 January 2006)[120]
# 18       No (abolished by law on 1 January 2008)[123]
# 23                 No (abolished by law in 2008)[128]
# 25                Yes (alternative service available)
# 26                        No (abolished in 2005)[129]
# 27  Yes (alternative service available).[130][131]...
# 33                Yes (alternative service available)
# 35                Yes (alternative service available)
# 36  No (suspended during peacetime in 2001).[134] ...
# 38  No (suspended during peacetime by the federal ...
# 39                Yes (alternative service available)
# 40  No (peacetime conscription abolished in 2004)[...
# 43                                                 No
# 47       No (suspended during peacetime in 2005)[138]
# 52  Yes[143] (abolished in 2007, reintroduced on J...
# 55  Yes[146] About 3,000–4,000 conscripts each yea...
# 56                                                 No
# 59                                                 No
# 61                                           Yes[150]
# 65  No. Active conscription suspended in 1997 (exc...
# 69                        No (abolished in 2006)[157]
# 70  Yes by law, but in practice people are not for...
# 73  No. Ended in 2009, but selective registration ...
# 74  No. Peacetime conscription abolished in 2004, ...
# 76                         No (ended in January 2007)
# 77                Yes (alternative service available)
# 80                  No (abolished on January 1, 2011)
# 83             No (abolished on January 1, 2006)[167]
# 84                                            No[168]
# 87     No (abolished by law on 31 December 2001)[171]
# 88  Yes. Abolished in 2010 but reintroduced in 201...
# 89           Yes (alternative service available)[173]
# 96                                           Yes[178]
# 98  Yes (abolished in 2013, reinstated in 2014 due...
# 99  No. Required from 1916 until 1920 and from 193...
