# %%
import pandas as pd, country_converter as coco

# %%
# Open .xlsx file
df = pd.read_excel('vat_substandard_rates.xlsx', sheet_name='VAT rates', skiprows=3)

# Remove bottom 11 rows
df = df[:-11].copy()

# Rename 'Unnamed: 0' to 'Country'
df.rename(columns={'Unnamed: 0': 'Country'}, inplace=True)

# Add 'ISO3' column
df['ISO3'] = coco.convert(names=df['Country'], to='ISO3')

df['ISO - numeric'] = coco.convert(names=df['Country'], to='UN')

# Add continent column
df['Continent'] = coco.convert(names=df['Country'], to='continent')

# Drop if not found
df = df[df['ISO3'] != 'not found'].copy()

# # Filter to Continent
# df = df[df['Continent'] == 'Europe'].reset_index(drop=True).copy()
# Out:
# Channel Islands not found in regex
# Channel Islands not found in regex
# Channel Islands not found in regex

# %%
# Clean `VAT/GST (standard)` column. Rules:
# If value is percentage (e.g. 20%), convert to decimal (e.g. 0.20)
# If value us 'no', convert to 0
# If value starts with percentage, then has other text, take the first percentage and convert to decimal
# If value is NaN, convert to 0

def clean_vat(row):
    if row['VAT/GST (standard)'] == 'no':
        return 0
    elif pd.isna(row['VAT/GST (standard)']):
        return 0
    else:
        # Convert value to string and split
        if '%' in str(row['VAT/GST (standard)']):
            value_string = str(row['VAT/GST (standard)']).split('%')[0]
            return float(value_string) / 100
        else:
            return row['VAT/GST (standard)']

df['vat_cleaned'] = df.apply(clean_vat, axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 20
#      17         else:
#      18             return row['VAT/GST (standard)']
# ---> 20 df['vat_cleaned'] = df.apply(clean_vat, axis=1)
#
# File ~/miniconda3/envs/datasci/lib/python3.11/site-packages/pandas/core/frame.py:10034, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10022 from pandas.core.apply import frame_apply
#   10024 op = frame_apply(
#   10025     self,
#   10026     func=func,
#    (...)
#   10032     kwargs=kwargs,
#   10033 )
# > 10034 return op.apply().__finalize__(self, method="apply")
#
# File ~/miniconda3/envs/datasci/lib/python3.11/site-packages/pandas/core/apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File ~/miniconda3/envs/datasci/lib/python3.11/site-packages/pandas/core/apply.py:965, in FrameApply.apply_standard(self)
#     964 def apply_standard(self):
# --> 965     results, res_index = self.apply_series_generator()
#     967     # wrap results
#     968     return self.wrap_results(results, res_index)
#
# File ~/miniconda3/envs/datasci/lib/python3.11/site-packages/pandas/core/apply.py:981, in FrameApply.apply_series_generator(self)
#     978 with option_context("mode.chained_assignment", None):
#     979     for i, v in enumerate(series_gen):
#     980         # ignore SettingWithCopy here in case the user mutates
# --> 981         results[i] = self.func(v, *self.args, **self.kwargs)
#     982         if isinstance(results[i], ABCSeries):
#     983             # If we have a view on v, we need to make a copy because
#     984             #  series_generator will swap out the underlying data
#     985             results[i] = results[i].copy(deep=False)
#
# Cell In[21], line 16, in clean_vat(row)
#      14 if '%' in str(row['VAT/GST (standard)']):
#      15     value_string = str(row['VAT/GST (standard)']).split('%')[0]
# ---> 16     return float(value_string) / 100
#      17 else:
#      18     return row['VAT/GST (standard)']
#
# ValueError: could not convert string to float: '0-20'

# %%
df.to_csv('imf_vat_europe.csv', index=False)

# %%
df
# Out:
#             Country           Income group              Region Country groups  \
# 0       Afghanistan            Low income        Southern Asia          MENAP
# 1           Albania   Upper middle income      Southern Europe            NaN
# 2           Algeria   Upper middle income      Northern Africa          MENAP
# 3    American Samoa   Upper middle income            Polynesia            NaN
# 4           Andorra  High income: nonOECD      Southern Europe            NaN
# ..              ...                    ...                 ...            ...
# 213       Venezuela  High income: nonOECD        South America          CELAC
# 214         Vietnam   Lower middle income   South-Eastern Asia          ASEAN
# 215           Yemen   Lower middle income          Middle East          MENAP
# 216          Zambia   Lower middle income       Eastern Africa           SADC
# 217        Zimbabwe            Low income       Eastern Africa           SADC
#
#                                     VAT/GST (standard)  \
# 0                                                   no
# 1                                                  20%
# 2                                                 0.19
# 3                                                  NaN
# 4                                                0.045
# ..                                                 ...
# 213                                               0.16
# 214  10%\n\n0%, 2%, 3% or 5% of the revenue for for...
# 215                                                 5%
# 216                                                16%
# 217                                              0.145
#
#                                      VAT/GST (reduced)  \
# 0                                                   no
# 1                                               0%, 6%
# 2                                               0%, 9%
# 3                                                  NaN
# 4                                      0%, 1% and 2.5%
# ..                                                 ...
# 213                                             0%, 8%
# 214                                             0%, 5%
# 215  0% (export of goods and services and internati...
# 216                                                 0%
# 217                                                 0%
#
#                            VAT/GST (increased) ISO3 Continent     id
# 0                                           no  AFG      Asia    4.0
# 1                                           no  ALB    Europe    8.0
# 2                                           no  DZA    Africa   12.0
# 3                                          NaN  ASM   Oceania   16.0
# 4    9.5% (for banking and financial services)  AND    Europe   20.0
# ..                                         ...  ...       ...    ...
# 213                                       0.31  VEN   America  862.0
# 214                                         no  VNM      Asia  704.0
# 215                              10%, 20%, 90%  YEM      Asia  887.0
# 216                                         no  ZMB    Africa  894.0
# 217                                         no  ZWE    Africa  716.0
#
# [217 rows x 10 columns]

# %% [markdown]
# Let's combine with TradingEconomics dataset on standard sales tax / vat rates.

# %%
# Open .xlsx file
df_te = pd.read_excel('vat_substandard_rates.xlsx', sheet_name='TE')

# %%
df_te
# Out:
#          Country  Last  Reference
# 0    Afghanistan  10.0 2022-12-01
# 1        Albania  20.0 2023-12-01
# 2        Algeria  19.0 2023-12-01
# 3        Andorra   4.5 2022-12-01
# 4         Angola  14.0 2023-12-01
# ..           ...   ...        ...
# 174      Vanuatu  15.0 2023-12-01
# 175    Venezuela  16.0 2023-12-01
# 176      Vietnam  10.0 2023-12-01
# 177       Zambia  16.0 2023-12-01
# 178     Zimbabwe  14.5 2023-12-01
#
# [179 rows x 3 columns]

# %% [markdown]
# ---

# %%
# Download and save world geojson file
url = 'https://unpkg.com/world-atlas@1.1.4/world/110m.json'

import requests
r = requests.get(url)
with open('world.geojson', 'wb') as f:
    f.write(r.content)

# %%
# Now, we want to remove overseas territories, and only keep Europe
import geopandas as gpd

# Open world geojson file
world = gpd.read_file('world.geojson')

# %%
# In `id` column, remove any leading zeroes, e.g. '003' with '3'
world['id'] = world['id'].str.lstrip('0')
world['Country'] = coco.convert(names=world['id'], to='ISO3')
world['Continent'] = coco.convert(names=world['id'], to='continent')
world['ISO3'] = coco.convert(names=world['id'], to='ISO3')

# Filter to Europe
europe = world[world['Continent'] == 'Europe'].copy()
# Out:
# -99 not found in ISOnumeric
# -99 not found in ISOnumeric
# -99 not found in ISOnumeric
# -99 not found in ISOnumeric
# -99 not found in ISOnumeric
# -99 not found in ISOnumeric
# -99 not found in ISOnumeric
# -99 not found in ISOnumeric
# -99 not found in ISOnumeric

# %%
# Save geopandas to geojson file
europe.to_file('europe.geojson', driver='GeoJSON')
