# %% [markdown]
# # UK Debt Analysis - DMO Data Cleaning
#
# This notebook demonstrates how to clean and process UK Debt DMO data, applying string functions, numerical transformations, and filtering to create a clean dataset.
#
# </br></br>
#
# First we load the dataset, instructing `pandas` to skip the first rows, which just contain metadata.

# %%
import pandas as pd

# Load the data and skip the first 12 rows
df = pd.read_csv("https://github.com/RDeconomist/RDeconomist.github.io/raw/refs/heads/main/data/GiltsInIssueRaw.csv", encoding='ISO-8859-1', skiprows=8)
df.head()
# Out:
#           Conventional Gilts     ISIN Code Redemption Date First Issue Date  \
# 0                Ultra-Short           NaN             NaN              NaN
# 1  0 1/8% Treasury Gilt 2023  GB00BL68HG94     31-Jan-2023      08-Apr-2020
# 2     0¾% Treasury Gilt 2023  GB00BF0HZ991     22-Jul-2023      20-Jul-2017
# 3     2¼% Treasury Gilt 2023  GB00B7Z53659     07-Sep-2023      12-Jun-2013
# 4  0 1/8% Treasury Gilt 2024  GB00BMGR2791     31-Jan-2024      07-Oct-2020
#
#   Dividend Dates Current/Next \nEx-dividend Date  \
# 0            NaN                             NaN
# 1     31 Jan/Jul                     20-Jan-2023
# 2     22 Jan/Jul                     12-Jan-2023
# 3      7 Mar/Sep                     24-Feb-2023
# 4     31 Jan/Jul                     20-Jan-2023
#
#   Total Amount in Issue \n(£ million nominal) Unnamed: 7 Unnamed: 8
# 0                                         NaN        NaN        NaN
# 1                                      33,824        NaN        NaN
# 2                                      34,359        NaN        NaN
# 3                                      35,922        NaN        NaN
# 4                                      35,551        NaN        NaN

# %% [markdown]
# <br><br>
# ## Step 1: Renaming columns
# We rename the columns to reflect the data they contain.

# %%
# Rename columns
df.columns = ['type', 'code', 'redemptionDate', 'issueDate', 'divDates', 'divNextDate', 'issueAmount', 'baseRPI', 'amountINCinfUplift']
df.head()
# Out:
#                         type          code redemptionDate     issueDate  \
# 0                Ultra-Short           NaN            NaN           NaN
# 1  0 1/8% Treasury Gilt 2023  GB00BL68HG94    31-Jan-2023   08-Apr-2020
# 2     0¾% Treasury Gilt 2023  GB00BF0HZ991    22-Jul-2023   20-Jul-2017
# 3     2¼% Treasury Gilt 2023  GB00B7Z53659    07-Sep-2023   12-Jun-2013
# 4  0 1/8% Treasury Gilt 2024  GB00BMGR2791    31-Jan-2024   07-Oct-2020
#
#      divDates   divNextDate issueAmount baseRPI amountINCinfUplift
# 0         NaN           NaN         NaN     NaN                NaN
# 1  31 Jan/Jul   20-Jan-2023      33,824     NaN                NaN
# 2  22 Jan/Jul   12-Jan-2023      34,359     NaN                NaN
# 3   7 Mar/Sep   24-Feb-2023      35,922     NaN                NaN
# 4  31 Jan/Jul   20-Jan-2023      35,551     NaN                NaN

# %% [markdown]
# <br><br>
# ## Step 2: Dropping unnecessary rows
# We drop rows with missing or invalid values in the columns `type`, `code`, and `redemptionDate`.

# %%
# Drop empty rows based on type, code, and redemptionDate
df = df[(df['type'] != "") & (df['code'] != "ISIN Code") & (df['code'] != "") & (df['redemptionDate'] != "")]
df.head()
# Out:
#                         type          code redemptionDate     issueDate  \
# 0                Ultra-Short           NaN            NaN           NaN
# 1  0 1/8% Treasury Gilt 2023  GB00BL68HG94    31-Jan-2023   08-Apr-2020
# 2     0¾% Treasury Gilt 2023  GB00BF0HZ991    22-Jul-2023   20-Jul-2017
# 3     2¼% Treasury Gilt 2023  GB00B7Z53659    07-Sep-2023   12-Jun-2013
# 4  0 1/8% Treasury Gilt 2024  GB00BMGR2791    31-Jan-2024   07-Oct-2020
#
#      divDates   divNextDate issueAmount baseRPI amountINCinfUplift
# 0         NaN           NaN         NaN     NaN                NaN
# 1  31 Jan/Jul   20-Jan-2023      33,824     NaN                NaN
# 2  22 Jan/Jul   12-Jan-2023      34,359     NaN                NaN
# 3   7 Mar/Sep   24-Feb-2023      35,922     NaN                NaN
# 4  31 Jan/Jul   20-Jan-2023      35,551     NaN                NaN

# %% [markdown]
#  <br><br>
# ## Step 3: Extracting the Gilt Types
# We split at the first 'T' or 'I' to extract the Gilt type.

# %%
df['giltType'] = df['type'].str.split(r'(T|I)', n=1) # Split the string starting at 'T' or 'I', keeping everything after it
df['giltType'] = df['giltType'].apply(lambda x: ''.join(x[1:]) if isinstance(x, list) and len(x) > 1 else pd.NA) # Apply logic to return the part from the first occurrence of 'T' or 'I', or NA if not found
df.head()
# Out:
#                         type          code redemptionDate     issueDate  \
# 0                Ultra-Short           NaN            NaN           NaN
# 1  0 1/8% Treasury Gilt 2023  GB00BL68HG94    31-Jan-2023   08-Apr-2020
# 2     0¾% Treasury Gilt 2023  GB00BF0HZ991    22-Jul-2023   20-Jul-2017
# 3     2¼% Treasury Gilt 2023  GB00B7Z53659    07-Sep-2023   12-Jun-2013
# 4  0 1/8% Treasury Gilt 2024  GB00BMGR2791    31-Jan-2024   07-Oct-2020
#
#      divDates   divNextDate issueAmount baseRPI amountINCinfUplift  \
# 0         NaN           NaN         NaN     NaN                NaN
# 1  31 Jan/Jul   20-Jan-2023      33,824     NaN                NaN
# 2  22 Jan/Jul   12-Jan-2023      34,359     NaN                NaN
# 3   7 Mar/Sep   24-Feb-2023      35,922     NaN                NaN
# 4  31 Jan/Jul   20-Jan-2023      35,551     NaN                NaN
#
#              giltType
# 0                <NA>
# 1  Treasury Gilt 2023
# 2  Treasury Gilt 2023
# 3  Treasury Gilt 2023
# 4  Treasury Gilt 2024

# %% [markdown]
# <br><br>
# ## Step 4: Extracting Coupon Information using String Functions
# We clean the Coupon info by considering only the text before the first 'T' or 'I' and decimalise fractions.

# %%
# Split the type column at the 'T' or 'I', whichever comes first
df['coupon'] = df['type'].str.split('T|I', expand=True)[0]


# There are some special fraction characters that we should replace
df['coupon'] = df['coupon'].str.replace('¾', ' 3/4').str.replace('¼', ' 1/4').str.replace('¼', ' 1/4').str.replace('½', ' 1/2')

def parse_coupon(coupon):
    # A function to parse the coupon string into a float by decimalising the fractions and summing the parts
    coupon = str(coupon)
    coupon = coupon.replace("%", "")
    coupon = coupon.split("Green Gilt")[0] # Remove the Green Gilt part if it exists
    # The coupon has multiple parts - always an integer then sometimes a fraction
    parts = coupon.split(" ")
    decimalised_parts = []
    for part in parts:
        if "/" in part:
            fraction_parts = part.split("/")
            decimalised = (pd.to_numeric(fraction_parts[0], errors='coerce') / pd.to_numeric(fraction_parts[1], errors='coerce'))
        else:
            decimalised = pd.to_numeric(part, errors='coerce')
        if not pd.isna(decimalised):
            decimalised_parts.append(decimalised) 
    return sum(decimalised_parts)

df['coupon'] = df['coupon'].apply(parse_coupon)

# %% [markdown]
# </br><br>
# ## Step 5: Converting string fields to numeric and standardising dates
# We convert the `issueAmount`, `baseRPI`, and `amountINCinfUplift` fields to numeric, handling any invalid entries.
# We also make sure the dates are properly formatted.

# %%
# Convert relevant columns to numeric (handling NaN values)
df['issueAmount'] = pd.to_numeric(df['issueAmount'].astype(str).str.replace(',', ''), errors='coerce')
df['baseRPI'] = pd.to_numeric(df['baseRPI'].astype(str).str.replace(',', ''), errors='coerce')
df['amountINCinfUplift'] = pd.to_numeric(df['amountINCinfUplift'].astype(str).str.replace(',', ''), errors='coerce')
df.head()

# Extract issue year and convert to numeric (handling NaN values)
df['issueYear'] = pd.to_numeric(df['issueDate'].astype(str).str[-4:], errors='coerce')
df.head()

# Extract issue year and convert to numeric (handling NaN values)
df['issueYear'] = pd.to_numeric(df['issueDate'].astype(str).str[-4:], errors='coerce')
df.head()

# Drop rows with missing values in type, code, and redemptionDate
df = df.dropna(subset=["type", "code", "redemptionDate"])
df.head()

df.sample(5)
# Out:
#                                       type          code redemptionDate  \
# 64  1 7/8% Index-linked Treasury Gilt 2022  GB00B1Z5HQ14    22-Nov-2022
# 25                  4¾% Treasury Gilt 2030  GB00B24FF097    07-Dec-2030
# 78  0 5/8% Index-linked Treasury Gilt 2042  GB00B3MYD345    22-Nov-2042
# 43               0 7/8% Treasury Gilt 2046  GB00BNNGP775    31-Jan-2046
# 48               0 5/8% Treasury Gilt 2050  GB00BMBL1F74    22-Oct-2050
#
#        issueDate    divDates   divNextDate  issueAmount    baseRPI  \
# 64   11-Jul-2007  22 May/Nov   11-Nov-2022      15743.0  205.65806
# 25   03-Oct-2007   7 Jun/Dec   28-Nov-2022      42819.0        NaN
# 78   24-Jul-2009  22 May/Nov   11-Nov-2022      12559.0  212.46452
# 43   20-Jan-2021  31 Jan/Jul   20-Jan-2023      20733.0        NaN
# 48   10-Jun-2020  22 Apr/Oct   13-Oct-2022      31916.0        NaN
#
#     amountINCinfUplift                         giltType  coupon  issueYear
# 64             26554.0  Index-linked Treasury Gilt 2022   1.875     2007.0
# 25                 NaN               Treasury Gilt 2030   4.750     2007.0
# 78             20364.0  Index-linked Treasury Gilt 2042   0.625     2009.0
# 43                 NaN               Treasury Gilt 2046   0.875     2021.0
# 48                 NaN               Treasury Gilt 2050   0.625     2020.0

# %% [markdown]
# <br><br>
# ## Step 6: Dropping invalid rows
# We drop rows that still contain missing values in critical columns such as `type`, `code`, and `redemptionDate`.

# %%
# Drop rows with missing values in type, code, and redemptionDate
df = df.query("giltType != '<NA>'")
df = df.dropna(subset=["giltType", "code", "redemptionDate"])
df.head()
# Out:
#                         type          code redemptionDate     issueDate  \
# 1  0 1/8% Treasury Gilt 2023  GB00BL68HG94    31-Jan-2023   08-Apr-2020
# 2     0¾% Treasury Gilt 2023  GB00BF0HZ991    22-Jul-2023   20-Jul-2017
# 3     2¼% Treasury Gilt 2023  GB00B7Z53659    07-Sep-2023   12-Jun-2013
# 4  0 1/8% Treasury Gilt 2024  GB00BMGR2791    31-Jan-2024   07-Oct-2020
# 5      1% Treasury Gilt 2024  GB00BFWFPL34    22-Apr-2024   25-Jul-2018
#
#      divDates   divNextDate  issueAmount  baseRPI  amountINCinfUplift  \
# 1  31 Jan/Jul   20-Jan-2023      33824.0      NaN                 NaN
# 2  22 Jan/Jul   12-Jan-2023      34359.0      NaN                 NaN
# 3   7 Mar/Sep   24-Feb-2023      35922.0      NaN                 NaN
# 4  31 Jan/Jul   20-Jan-2023      35551.0      NaN                 NaN
# 5  22 Apr/Oct   13-Oct-2022      35638.0      NaN                 NaN
#
#              giltType  coupon  issueYear
# 1  Treasury Gilt 2023   0.125     2020.0
# 2  Treasury Gilt 2023   0.750     2017.0
# 3  Treasury Gilt 2023   2.250     2013.0
# 4  Treasury Gilt 2024   0.125     2020.0
# 5  Treasury Gilt 2024   1.000     2018.0

# %% [markdown]
# <br><br>
# ## Step 9: Sorting and calculating cumulative totals <br><br>
# We sort the data by `issueYear` and calculate the cumulative total for `issueAmount`.

# %%
# Sort by issueYear and calculate cumulative total
df = df.sort_values('issueYear')
df['totalCumulative'] = df['issueAmount'].cumsum()
df.head()
# Out:
#                                        type          code redemptionDate  \
# 94     2½% Index-linked Treasury Stock 2024  GB0008983024    17-Jul-2024
# 95  4 1/8% Index-linked Treasury Stock 2030  GB0008932666    22-Jul-2030
# 20                   6% Treasury Stock 2028  GB0002404191    07-Dec-2028
# 28                  4¼% Treasury Stock 2032  GB0004893086    07-Jun-2032
# 8                    5% Treasury Stock 2025  GB0030880693    07-Mar-2025
#
#        issueDate    divDates   divNextDate  issueAmount     baseRPI  \
# 94   30-Dec-1986  17 Jan/Jul   06-Jan-2023       6821.0   97.667934
# 95   12-Jun-1992  22 Jan/Jul   12-Jan-2023       4841.0  135.100000
# 20   29-Jan-1998   7 Jun/Dec   28-Nov-2022      20256.0         NaN
# 28   25-May-2000   7 Jun/Dec   28-Nov-2022      40331.0         NaN
# 8    27-Sep-2001   7 Mar/Sep   24-Feb-2023      37339.0         NaN
#
#     amountINCinfUplift                          giltType  coupon  issueYear  \
# 94             22363.0  Index-linked Treasury Stock 2024   2.500     1986.0
# 95             11474.0  Index-linked Treasury Stock 2030   4.125     1992.0
# 20                 NaN               Treasury Stock 2028   6.000     1998.0
# 28                 NaN               Treasury Stock 2032   4.250     2000.0
# 8                  NaN               Treasury Stock 2025   5.000     2001.0
#
#     totalCumulative
# 94           6821.0
# 95          11662.0
# 20          31918.0
# 28          72249.0
# 8          109588.0

# %% [markdown]
# <br><br>
# ## Step 10: Exporting the cleaned data
# Finally, we export the cleaned dataset to a CSV file.

# %%
# Export cleaned data to CSV
df.to_csv("GiltsInIssueClean.csv", index=False)

# Keep just the columns we want
df = df[['giltType', 'code', 'issueYear', 'issueAmount', 'totalCumulative', 'coupon']]

# Display the cleaned DataFrame
df
# Out:
#                             giltType          code  issueYear  issueAmount  \
# 94  Index-linked Treasury Stock 2024  GB0008983024     1986.0       6821.0
# 95  Index-linked Treasury Stock 2030  GB0008932666     1992.0       4841.0
# 20               Treasury Stock 2028  GB0002404191     1998.0      20256.0
# 28               Treasury Stock 2032  GB0004893086     2000.0      40331.0
# 8                Treasury Stock 2025  GB0030880693     2001.0      37339.0
# ..                               ...           ...        ...          ...
# 49                Treasury Gilt 2051  GB00BLH38158     2021.0      26049.0
# 75   Index-linked Treasury Gilt 2039  GB00BLH38265     2021.0       6303.0
# 21                Treasury Gilt 2029  GB00BLPK7227     2021.0      17544.0
# 15                Treasury Gilt 2027  GB00BL6C7720     2022.0       4445.0
# 60                Treasury Gilt 2073  GB00BLBDX619     2022.0      10107.0
#
#     totalCumulative  coupon
# 94           6821.0   2.500
# 95          11662.0   4.125
# 20          31918.0   6.000
# 28          72249.0   4.250
# 8          109588.0   5.000
# ..              ...     ...
# 49        1989151.0   1.250
# 75        1995454.0   0.125
# 21        2012998.0   0.500
# 15        2017443.0   4.125
# 60        2027550.0   1.125
#
# [87 rows x 6 columns]
