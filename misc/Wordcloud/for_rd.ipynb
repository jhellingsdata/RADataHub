# %%
import pandas as pd

# %%
df = pd.read_excel("wc_data.xlsx")
# repeat each term by its value
df = df.loc[df.index.repeat(df['value'])]
terms = df.term.values

for term in terms:
    print(term)
# Out:
# Constraints
# Constraints
# Constraints
# Constraints
# Timing
# Timing
# Timing
# Timing
# Timing
# Timing
# Timing
# Timing
# Timing
# Timing
# Timing
# Timing
# Timing
# Timing
# Timing
# Timing
# Timing
# Timing
# Timing
# Timing
# Elections
# Elections
# Elections
# Elections
# Elections
# Personalities
# Personalities
# Personalities
# Personalities
# Personalities
# Personalities
# Personalities
# Personalities
# Personalities
# Personalities
# Personalities
# Personalities
# Personalities
# Personalities
# Personalities
# Personalities
# Personalities
# Personalities
# Party allegiances
# Party allegiances
# Party allegiances
# Party allegiances
# Party allegiances
# Party allegiances
# Party allegiances
# Egos
# Egos
# Egos
# Egos
# Egos
# Egos
# Egos
# Egos
# Egos
# Egos
# Egos
# Egos
# Egos
# Egos
# Budgets
# Budgets
# Budgets
# Budgets
# Budgets
# Budgets
# Budgets
# Budgets
# Budgets
# Budgets
# Budgets
# Budgets
# Budgets
# Budgets
# Budgets
# Budgets
# Budgets
# ...
