# %%
import pandas as pd
import numpy as np
import altair as alt
import eco_style
import os
alt.themes.enable("light")
# Out:
# ThemeRegistry.enable('light')

# %%
df = pd.read_csv("https://github.com/zonination/emperors/blob/master/emperors.csv?raw=true", encoding="latin").drop(columns=["index"])
df.to_csv("emperors.csv", index=False)

# %%
df = pd.read_csv("emperors.csv", encoding="latin")

df = df.rename(columns={
    "reign.end": "end",
    "reign.start": "start",
})

def date_to_float(date_str):
    if isinstance(date_str, str):
        try:
            parts = date_str.split('-')
            year = int(parts[0])
            month = int(parts[1])
            day = int(parts[2])
            # Approximate fractional year
            return year + (month - 1) / 12 + (day - 1) / 365.25
        except:
            return None
    return None

df["start"] = df["start"].apply(date_to_float)
df["end"] = df["end"].apply(date_to_float)

# apply a very little bit of delta to each end date to stop perfect  overlaps
df["end"] = df["end"] + np.random.uniform(0, 0.1, size=len(df))

# Make August' start negative
df.loc[df["name"] == "Augustus", "start"] = -26.041068

df = df.sort_values(by=["start", "end"], ascending=[True, True])

df = df.reset_index()
df['index'] = df.index + 1

# add in a 0,0 row
df = pd.concat([pd.DataFrame({"start": [-28], "end": [-28], "index": 0, "name": [""]}), df], ignore_index=True)


area = alt.Chart(df.query("end <= 306")).mark_area(
    color="#36b7b4",
    interpolate="step-before").encode(
        x=alt.X("end:Q", title="Year", 
                axis=alt.Axis(
                    labelExpr="datum.label + (datum.value < 0 ? ' BCE' : ' CE')",
                    values=[-25, 0, 50, 100, 150, 200, 250, 300],
                ),
                scale=alt.Scale(domain=[-28, 306])),
        y=alt.Y("index:Q", 
                axis=alt.Axis(
                    labelExpr="datum.label+(datum.value == 50 ? ' Emperors' : '')"
                ),
                title=""),
    )

# Shading for the crisis of the third century
crisis_shade = alt.Chart(pd.DataFrame({
    "start": [235],
    "end": [285],
    "label": ["Crisis of the Third Century"]
    })).mark_rect(
        fill="lightgray",
        opacity=0.5
    ).encode(
        x=alt.X("start:Q", title="Year"),
        x2=alt.X2("end:Q"),
    )

emperors_to_label = ["Augustus", "Diocletian"]
emperor_labels = alt.Chart(df.query("name in @emperors_to_label")).mark_text(
    align="left",
    baseline="middle",
    dy=alt.expr("datum.name === 'Augustus' ? -10 : 5"),
    dx=alt.expr("datum.name === 'Augustus' ? -15 : 20"),
    text=alt.expr("'('+datum.name+')'"),
    color="rgba(0, 0, 0, 0.4)",
).encode(
    x=alt.X("start:Q", title="Year"),
    y=alt.Y("index:Q", title=""),
)

other_labels_df = pd.DataFrame([
    {"label": "Crisis of the\nThird Century", "year": (284 + 235) / 2},
])

other_labels_df["label"] = other_labels_df["label"].apply(lambda x: x.split("\n"))

other_lables = alt.Chart(other_labels_df).mark_text(
    align="center",
    baseline="middle",
    dy=-9,
    dx=3,
    color="black",
).encode(
    x=alt.X("year:Q", title="Year"),
    y=alt.value(-10),
    text="label:N"
)


event_rules = alt.Chart(pd.DataFrame([
    {"label": "Year of the\nFour Emperors", "year": 69},
])).mark_rule(
    color="black",
    strokeDash=[3, 5],
).encode(
    x=alt.X("year:Q", title="Year"),
)

chart = crisis_shade+ area +emperor_labels+other_lables

chart = chart.properties(
    width=350,
    height=225
)

chart.save("cumulative_emperors.png", scale_factor=3)
chart.save("cumulative_emperors.json")
chart
# Out:
# alt.LayerChart(...)

# %%
df.query("index <= 49")
# Out:
#          start         end  index                name  \
# 0   -28.000000  -28.000000      0
# 1   -26.041068   14.663674      1            Augustus
# 2    14.713210   37.259539      2            Tiberius
# 3    37.213210   41.084085      3            Caligula
# 4    41.065708   54.874615      4            Claudius
# 5    54.782854   68.493618      5                Nero
# 6    68.435832   69.124095      6               Galba
# 7    69.038330   69.384990      7                Otho
# 8    69.293806   70.053681      8           Vitellius
# 9    69.971424   79.577188      9           Vespasian
# 10   79.479637   81.778785     10               Titus
# 11   81.702259   96.755531     11            Domitian
# 12   96.713210   98.077246     12               Nerva
# 13   98.073922  117.651914     13              Trajan
# 14  117.610712  138.538899     14             Hadrian
# 15  138.524641  161.233545     15       Antonius Pius
# 16  161.183094  169.261117     16        Lucius Verus
# 17  161.183094  180.225896     17     Marcus Aurelius
# 18  177.000000  193.074687     18            Commodus
# 19  193.000000  193.339117     19            Pertinax
# 20  193.240589  193.571169     20     Didius Julianus
# 21  193.271903  211.119376     21    Septimus Severus
# 22  198.000000  217.274956     22           Caracalla
# 23  209.000000  212.084803     23                Geta
# 24  217.277379  218.483876     24            Macrinus
# 25  218.435832  222.269816     25          Elagabalus
# 26  222.199521  235.268416     26   Severus Alexander
# 27  235.218686  238.500065     27         Maximinus I
# 28  238.224162  238.344814     28           Gordian I
# 29  238.224162  238.369041     29          Gordian II
# 30  238.307495  238.598173     30            Balbinus
# 31  238.307495  238.617763     31            Pupienus
# 32  238.307495  244.186111     32         Gordian III
# 33  244.118925  249.802407     33            Philip I
# 34  249.750000  251.513723     34       Trajan Decius
# 35  251.454997  251.817578     35           Hostilian
# 36  251.454997  253.681419     36  Trebonianus Gallus
# 37  253.621663  253.846192     37            Aemilian
# 38  253.788330  260.007899     38            Valerian
# 39  253.788330  268.752153     39           Gallienus
# 40  268.704997  270.084515     40   Claudius Gothicus
# 41  270.038330  270.320950     41          Quintillus
# 42  270.704997  275.779816     42            Aurelian
# 43  275.732375  276.532896     43             Tacitus
# 44  276.454997  276.708903     44             Florian
# 45  276.704997  282.774122     45              Probus
# 46  282.750000  283.638852     46               Carus
# 47  283.583333  284.929748     47            Numerian
# 48  283.583333  285.633943     48             Carinus
# 49  284.885352  305.348029     49          Diocletian
#
#                                             name.full       birth       death  \
# 0                                                 NaN         NaN         NaN
# 1               IMPERATOR CAESAR DIVI FILIVS AVGVSTVS  0062-09-23  0014-08-19
# 2        TIBERIVS CAESAR DIVI AVGVSTI FILIVS AVGVSTVS  0041-11-16  0037-03-16
# 3             GAIVS IVLIVS CAESAR AVGVSTVS GERMANICVS  0012-08-31  0041-01-24
# 4        TIBERIVS CLAVDIVS CAESAR AVGVSTVS GERMANICVS  0009-08-01  0054-10-13
# 5            NERO CLAVDIVS CAESAR AVGVSTVS GERMANICVS  0037-12-15  0068-06-09
# 6             SERVIVS SVLPICIVS GALBA CAESAR AVGVSTVS  0002-12-24  0069-01-15
# 37         CAESAR MARCVS AEMILIVS AEMILIANVS AVGVSTVS  0207-01-01  0253-10-15
# 38        CAESAR PVBLIVS LICINIVS VALERIANVS AVGVSTVS  0195-01-01  0264-01-01
# 39  CAESAR PVBLIVS LICINIVS EGNATIVS GALLIENVS AVG...  0218-01-01  0268-09-15
# 40           CAESAR MARCVS AVRELIVS CLAVDIVS AVGVSTVS  0213-05-10  0270-01-15
# 41  CAESAR MARCVS AVRELIVS CLAVDIVS QVINTILLVS AVG...  0212-01-01  0270-04-15
# 42         CAESAR LVCIVS DOMITIVS AVRELIANVS AVGVSTVS  0214-09-09  0275-09-15
# 43           CAESAR MARCVS CLAVDIVSÂ TACITVS AVGVSTVS  0200-01-01  0276-06-15
# 44            CAESAR MARCVS ANNIVS FLORIANVS AVGVSTVS         NaN  0276-09-15
# 45             CAESAR MARCVS AVRELIVS PROBVS AVGVSTVS  0232-08-19  0282-10-01
# 46              CAESAR MARCVS AVRELIVS CARVS AVGVSTVS  0230-01-01  0283-08-01
# 47  CAESAR MARCVS AVRELIVS NVMERIVS NVMERIANVS AVG...         NaN  0284-11-20
# 48            CAESAR MARCVS AVRELIVS CARINVS AVGVSTVS         NaN  0285-08-01
# 49  CAESAR GAIVS AVRELIVS VALERIVS DIOCLETIANVS AV...  0244-12-22  0311-12-03
#
#            birth.cty           birth.prv                             rise  \
# 0                NaN                 NaN                              NaN
# 1               Rome              Italia                       Birthright
# 2               Rome              Italia                       Birthright
# 3            Antitum              Italia                       Birthright
# 4           Lugdunum  Gallia Lugdunensis                       Birthright
# 5            Antitum              Italia                       Birthright
# 6          Terracina              Italia                     Seized Power
# 7         Terentinum              Italia  Appointment by Praetorian Guard
# 8               Rome              Italia                     Seized Power
# 9          Falacrine              Italia                     Seized Power
# 10              Rome              Italia                       Birthright
# 11              Rome              Italia                       Birthright
# 12             Narni              Italia            Appointment by Senate
# 13           Italica    Hispania Baetica                       Birthright
# 14           Italica    Hispania Baetica                       Birthright
# 15          Lanuvium              Italia                       Birthright
# 16              Rome              Italia                       Birthright
# 17              Rome              Italia                       Birthright
# 18          Lanuvium              Italia                       Birthright
# 19              Alba              Italia  Appointment by Praetorian Guard
# 20             Milan              Italia                         Purchase
# 21      Leptis Magna               Libya                     Seized Power
# 22          Lugdunum  Gallia Lugdunensis                       Birthright
# 23              Rome              Italia                       Birthright
# 24      Iol Caesarea          Mauretania                     Seized Power
# 25             Emesa               Syria                       Birthright
# 26     Arca Caesarea               Syria                       Birthright
# 27               NaN              Thrace  Appointment by Praetorian Guard
# 28               NaN             Phrygia            Appointment by Senate
# 29               NaN             Unknown            Appointment by Senate
# 30               NaN             Unknown            Appointment by Senate
# 31               NaN             Unknown            Appointment by Senate
# 32              Rome              Italia            Appointment by Senate
# 33            Shahba               Syria                     Seized Power
# 34           Budalia   Pannonia Inferior              Appointment by Army
# 35           Sirmium            Pannonia                       Birthright
# 36               NaN              Italia              Appointment by Army
# 37               NaN              Africa              Appointment by Army
# 38               NaN             Unknown              Appointment by Army
# 39               NaN             Unknown                       Birthright
# 40           Sirmium            Pannonia                     Seized Power
# 2   birth is BCE. Assign negative for correct ISO ...  Reddit user zonination
# 3   assassination may have only involved the Praet...  Reddit user zonination
# 4   birth is BCE. Assign negative for correct ISO ...  Reddit user zonination
# 5                                                 NaN  Reddit user zonination
# 6   birth is BCE. Assign negative for correct ISO ...  Reddit user zonination
# 7                                                 NaN                     NaN
# 8                                                 NaN                     NaN
# 9                                                 NaN                     NaN
# 10                                                NaN                     NaN
# 11                                                NaN                     NaN
# 12                                                NaN                     NaN
# 13                                                NaN                     NaN
# 14                                                NaN                     NaN
# 15                                                NaN                     NaN
# 16                     death, reign.end are estimates                     NaN
# 17                                                NaN                     NaN
# 18                 reign.start is only valid for year                     NaN
# 19                                                NaN                     NaN
# 20                     birth could also be 0137-02-02                     NaN
# 21                                                NaN                     NaN
# 22                 reign.start is only valid for year                     NaN
# 23                 reign.start is only valid for year                     NaN
# 24                       birth is only valid for year                     NaN
# 25                             birth is only estimate                     NaN
# 26                                                NaN                     NaN
# 27  birth is only estimate. Death, reign.end are e...                     NaN
# 28                            birth is only estimate.                     NaN
# 29                            birth is only estimate.                     NaN
# 30                            birth is only estimate.                     NaN
# 31                            birth is only estimate.                     NaN
# 32                                                NaN                     NaN
# 33                         reign.end is only estimate                     NaN
# 34  birth is only estimate. Reign.end is only esti...                     NaN
# 35  birth is only estimate. Reign.end is only esti...                     NaN
# 36  birth, death, reign.end, reign.start are estim...                     NaN
# 37  birth, death, reign.end, reign.start are estim...                     NaN
# 38  birth, death, reign.end, reign.start are estim...                     NaN
# 39  birth, death, reign.end, reign.start are estim...                     NaN
# 40  birth, death, reign.end, reign.start are estim...                     NaN
# 41  birth, death, reign.end, reign.start are estim...                     NaN
# 42                                                NaN                     NaN
# 43             birth, death, reign.end are estimates.                     NaN
# 44  death, reign.end, reign.start are estimates. B...                     NaN
# 45  birth, death, reign.end, reign.start are estim...                     NaN
# 46  birth, death, reign.end, reign.start are estim...                     NaN
# 47  death, reign.end, reign.start are estimates. B...                     NaN
# 48  death, reign.end, reign.start are estimates. B...                     NaN
# 49                                                NaN                     NaN

# %% [markdown]
# # Silver Content

# %%
# Out:
# alt.Chart(...)

# %%
dfs = []

for path in os.listdir("silver_content_velatrix_walker_1986"):
    df =  pd.read_csv(f"silver_content_velatrix_walker_1986/{path}", header=None, names=["year", "silver_content"])
    df['period'] = path.split(".")[0]
    dfs.append(df)

df = pd.concat(dfs, ignore_index=True)
df['year'] = df.year.round().astype(int)
df['silver_content'] = df.silver_content.round(1)/100

# Remove the 0.36-0.37 Severans - an error in the tracing
df = df.query("(silver_content > 0.38)")
points_df = df.copy()


points = alt.Chart(points_df).mark_circle().encode(
    x=alt.X("year:Q", title=""),
    y=alt.Y("silver_content:Q", title=""),
    color=alt.Color("period:N", title="", 
                    legend=alt.Legend(
                        orient="top",
                        #title="Walker (1986)",
                        title="",
                        titleFontWeight="normal",
                        titleOrient="top",
                        columns=4
                    ),
                    scale=alt.Scale(
                        domain=["Judio-Claudians", "Flavians", "Antonines", "Civil War (AD 69)", "Civil War (AD 193)", "Severans", "Third Century Crisis"],
                    )),
    tooltip=["year:Q", "silver_content:Q", "period:N"]
    
)

points

df = pd.read_csv("Silver_content-Pense - The Decline and Fall of The Roman Denarius.csv", header=None)
df.columns = ["year", "silver_content"]
df['year'] = df.year.round().astype(int)
df['silver_content'] = df.silver_content.round(0)/100
df['series'] = "Silver content (Pense, 1992)"

df['label'] = ''
df.iloc[-1,-1] = "Pense, 1992"

line = alt.Chart(df).mark_line(
    color="lightgrey",
    strokeWidth=2,
    ).encode(
        color=alt.Color("series:N", title="",
                        legend=None,
                        scale=alt.Scale(
                            domain=["Silver content (Pense, 1992)"],
                            range=["lightgrey"],
                        )),
        x=alt.X("year:Q", title="",
                axis=alt.Axis(
                    labelExpr="datum.label + (datum.value < 0 ? ' BCE' : ' CE')",
                ),
                scale=alt.Scale()),
        y=alt.Y("silver_content:Q", title="",
                axis=alt.Axis(
                    format="%",
                    labelExpr="datum.label + (datum.value == 1 ? ' Silver': '')"
                ),
                scale=alt.Scale(domain=[0, 1])),
    )

chart = (line + points).resolve_scale(
    color="independent"
).properties(
    width=350,
    height=225,
)

chart.save("silver_content.png", scale_factor=3)
chart.save("silver_content.json")
chart
# Out:
# alt.LayerChart(...)

# %%
df
# Out:
#     year  silver_content                        series        label
# 0   -123            0.97  Silver content (Pense, 1992)
# 1   -115            0.97  Silver content (Pense, 1992)
# 2   -107            0.97  Silver content (Pense, 1992)
# 3   -102            0.97  Silver content (Pense, 1992)
# 4    -97            0.97  Silver content (Pense, 1992)
# ..   ...             ...                           ...          ...
# 65   271            0.18  Silver content (Pense, 1992)
# 66   272            0.06  Silver content (Pense, 1992)
# 67   277            0.02  Silver content (Pense, 1992)
# 68   283            0.02  Silver content (Pense, 1992)
# 69   286            0.02  Silver content (Pense, 1992)  Pense, 1992
#
# [70 rows x 4 columns]

# %% [markdown]
# # Price edict

# %%
prices = [{
        "title": "Olive Oil\n(Extra virgin, ~540ml)",
        "price": 40,
        "group": "Oil"
    },
    {
        "title": "Olive Oil\n(Second pressing, ~540ml)",
        "price": 24,
        "group": "Oil"
    },
    {
        "title": "Olive Oil\n(Ordinary, ~540ml)",
        "price": 12,
        "group": "Oil"
    },
    {
        "title": "Pork\n(330g)",
        "price": 12,
        "group": "Meat"
    },
    {
        "title": "Beef\n(330g)",
        "price": 8,
        "group": "Meat"
    },
    {
        "title": "Sow's udder\n(330g)",
        "price": 20,
        "group": "Meat"
    },
    {
        "title": "Snails\n(20, largest)",
        "price": 20,
        "group": "Meat"
    },
    {
        "title": "Farm labourer\n(w/ maintenance, 1 day)",
        "price": 25,
        "group": "Labour"
    },
    {
        "title": "Carpenter\n(w/ maintenance, 1 day)",
        "price": 50,
        "group": "Labour"
    },
    {
        "title": "Figure painter\n(w/ maintenance, 1 day)",
        "price": 150,
        "group": "Labour"
    },
    {
        "title": "Wine\n(Year old, ~540ml)",
        "price": 16,
        "group": "Alcohol"
    },
    {
        "title": "Wheat beer\n(~540ml)",
        "price": 4,
        "group": "Alcohol"
    },
    {
        "title": "Spiced Wine\n(~540ml)",
        "price": 24,
        "group": "Alcohol"
    }
    
    
    ]

# %%
df = pd.DataFrame(prices)
df['title'] = df['title'].apply(lambda x: x.split("\n"))

# sort by group and then by price
df = df.sort_values(by=["group", "price"], ascending=[True, True])
df = df.reset_index()
df = df.rename(columns={"index": "rank"})


df_prices = df[df['group'] != "Labour"]
df_wages = df[df['group'] == "Labour"]

# Define common x encoding to ensure shared scale
x_shared = alt.X("price:Q", title="", axis=alt.Axis(
    labelAlign=alt.expr("datum.value == 160 ? 'left' : 'center'"),
    labelExpr="datum.label + ((datum.value == 160 | datum.value == -1) ? ' denarii' : '')"),)

# Price chart
chart_prices = alt.Chart(df_prices).mark_bar().encode(
    y=alt.Y("title:N", title="", sort=alt.EncodingSortField("rank:Q", order="ascending")),
    x=x_shared,
    color=alt.Color("group:N", legend=alt.Legend(
        orient="top",
        title="",
        values=["Oil", "Meat", "Alcohol", "Labour"],
    ))
).properties(
    title=alt.TitleParams(
        text="Prices",
        align="left",
        fontWeight="normal",
        anchor="start",
        fontSize=11,
        frame="group",
    ),
    height=250,
    width=350
)

# Wages chart
chart_wages = alt.Chart(df_wages).mark_bar().encode(
    y=alt.Y("title:N", title="", sort=alt.EncodingSortField("rank:Q", order="ascending")),
    x=x_shared,
    color=alt.Color("group:N")
).properties(
    title= alt.TitleParams(
        text="Wages",
        align="left",
        fontWeight="normal",
        anchor="start",
        fontSize=11,
        frame="group",
    ),
    height=100,
    width=350
)

chart = chart_prices & chart_wages
chart.save("prices_wages.png", scale_factor=3)
chart.save("prices_wages.json")
chart
# Out:
# alt.VConcatChart(...)

# %%
df
# Out:
#    rank                                      title  price   group
# 0     6   [Farm labourer, (w/ maintenance, 1 day)]     25  Labour
# 1     7   [Farm labourer, (w/ maintenance, 1 day)]     25  Labour
# 2     8       [Carpenter, (w/ maintenance, 1 day)]     50  Labour
# 3     9  [Figure painter, (w/ maintenance, 1 day)]    150  Labour
# 4     4                             [Beef, (330g)]      8    Meat
# 5     3                             [Pork, (330g)]     12    Meat
# 6     5                      [Sow's udder, (330g)]     20    Meat
# 7     2            [Olive Oil, (Ordinary, ~540ml)]     12     Oil
# 8     1     [Olive Oil, (Second pressing, ~540ml)]     24     Oil
# 9     0        [Olive Oil, (Extra virgin, ~540ml)]     40     Oil

# %%
points_df.period.unique()
# Out:
# array(['Civil War (AD69)', 'Severans', 'Antonines', 'Judio-Claudians',
#        'Flavians', 'Civil War (AD 193)', 'Third Century Crisis'],
#       dtype=object)

# %%
area
# Out:
# alt.Chart(...)

# %%
df['length'] = df['end'] - df['start']
df.sort_values(by='length', ascending=False).query("end<306")
# Out:
#          start         end  index                name  \
# 1   -26.041068   14.673420      1            Augustus
# 15  138.524641  161.250270     15       Antonius Pius
# 2    14.713210   37.275983      2            Tiberius
# 14  117.610712  138.605464     14             Hadrian
# 49  284.885352  305.394717     49          Diocletian
# 13   98.073922  117.604588     13              Trajan
# 22  198.000000  217.269310     22           Caracalla
# 50  286.250000  305.335887     50            Maximian
# 17  161.183094  180.219517     17     Marcus Aurelius
# 21  193.271903  211.160744     21    Septimus Severus
# 18  177.000000  193.095410     18            Commodus
# 11   81.702259   96.792415     11            Domitian
# 39  253.788330  268.786418     39           Gallienus
# 19           CAESAR PVBLIVS HELVIVS PERTINAX AVGVSTVS  0126-08-01  0193-03-28
# 7                 MARCVS SALVIVS OTHO CAESAR AVGVSTVS  0032-04-28  0069-04-16
# 37         CAESAR MARCVS AEMILIVS AEMILIANVS AVGVSTVS  0207-01-01  0253-10-15
# 20     CAESAR MARCVS DIDIVS SEVERVS IVLIANVS AVGVSTVS  0133-01-30  0193-07-01
# 29  CAESAR MARCVS ANTONIVS GORDIANVS SEMPRONIANVS ...  0192-01-01  0238-04-12
# 28  CAESAR MARCVS ANTONIVS GORDIANVS SEMPRONIANVS ...  0159-01-01  0238-04-12
# 0                                                 NaN         NaN         NaN
#
#            birth.cty           birth.prv                             rise  \
# 1               Rome              Italia                       Birthright
# 15          Lanuvium              Italia                       Birthright
# 2               Rome              Italia                       Birthright
# 14           Italica    Hispania Baetica                       Birthright
# 49            Salona           Dalmatian                     Seized Power
# 13           Italica    Hispania Baetica                       Birthright
# 22          Lugdunum  Gallia Lugdunensis                       Birthright
# 50           Sirmium            Pannonia           Appointment by Emperor
# 17              Rome              Italia                       Birthright
# 21      Leptis Magna               Libya                     Seized Power
# 18          Lanuvium              Italia                       Birthright
# 11              Rome              Italia                       Birthright
# 39               NaN             Unknown                       Birthright
# 4           Lugdunum  Gallia Lugdunensis                       Birthright
# 5            Antitum              Italia                       Birthright
# 26     Arca Caesarea               Syria                       Birthright
# 9          Falacrine              Italia                     Seized Power
# 16              Rome              Italia                       Birthright
# 38               NaN             Unknown              Appointment by Army
# 45           Sirmium            Pannonia              Appointment by Army
# 32              Rome              Italia            Appointment by Senate
# 33            Shahba               Syria                     Seized Power
# 42           Sirmium            Pannonia              Appointment by Army
# 3            Antitum              Italia                       Birthright
# 25             Emesa               Syria                       Birthright
# 27               NaN              Thrace  Appointment by Praetorian Guard
# 23              Rome              Italia                       Birthright
# 10              Rome              Italia                       Birthright
# 36               NaN              Italia              Appointment by Army
# 48               NaN             Unknown                       Birthright
# 34           Budalia   Pannonia Inferior              Appointment by Army
# 12             Narni              Italia            Appointment by Senate
# 47               NaN             Unknown                       Birthright
# 40           Sirmium            Pannonia                     Seized Power
# 24      Iol Caesarea          Mauretania                     Seized Power
# 46             Narbo  Gallia Narbonensis                     Seized Power
# 43  Interamna Nahars              Italia            Appointment by Senate
# 8               Rome              Italia                     Seized Power
# 6          Terracina              Italia                     Seized Power
# 35           Sirmium            Pannonia                       Birthright
# 31               NaN             Unknown            Appointment by Senate
# 30               NaN             Unknown            Appointment by Senate
# 44               NaN             Unknown                       Birthright
# 41           Sirmium            Pannonia                       Birthright
# 19              Alba              Italia  Appointment by Praetorian Guard
# 7         Terentinum              Italia  Appointment by Praetorian Guard
# 37               NaN              Africa              Appointment by Army
# 20             Milan              Italia                         Purchase
# 29               NaN             Unknown            Appointment by Senate
# 28               NaN             Phrygia            Appointment by Senate
# 0                NaN                 NaN                              NaN
#
#              cause            killer         dynasty         era  \
# 1    Assassination              Wife  Julio-Claudian  Principate
# 15  Natural Causes           Disease  Nerva-Antonine  Principate
# 2    Assassination     Other Emperor  Julio-Claudian  Principate
# 14  Natural Causes     Heart Failure  Nerva-Antonine  Principate
# 49  Natural Causes           Disease   Constantinian    Dominate
# 13  Natural Causes           Disease  Nerva-Antonine  Principate
# 22   Assassination     Other Emperor         Severan  Principate
# 50         Suicide     Other Emperor   Constantinian    Dominate
# 17  Natural Causes           Disease  Nerva-Antonine  Principate
# 21  Natural Causes           Disease         Severan  Principate
# 18   Assassination  Praetorian Guard  Nerva-Antonine  Principate
# 11   Assassination   Court Officials         Flavian  Principate
# 39   Assassination          Own Army         Gordian  Principate
# 4    Assassination              Wife  Julio-Claudian  Principate
# 5          Suicide            Senate  Julio-Claudian  Principate
# 26   Assassination          Own Army         Severan  Principate
# 9   Natural Causes           Disease         Flavian  Principate
# 16  Natural Causes           Disease  Nerva-Antonine  Principate
# 38       Captivity     Opposing Army         Gordian  Principate
# 45   Assassination          Own Army         Gordian  Principate
# 32  Died in Battle     Opposing Army         Gordian  Principate
# 33       Execution     Other Emperor         Gordian  Principate
# 42   Assassination  Praetorian Guard         Gordian  Principate
# 3    Assassination            Senate  Julio-Claudian  Principate
# 25   Assassination  Praetorian Guard         Severan  Principate
# 27   Assassination  Praetorian Guard         Gordian  Principate
# 23   Assassination     Other Emperor         Severan  Principate
# 10  Natural Causes           Disease         Flavian  Principate
# 36   Assassination     Other Emperor         Gordian  Principate
# 48  Died in Battle     Opposing Army         Gordian  Principate
# 34  Died in Battle     Opposing Army         Gordian  Principate
# 12  Natural Causes           Disease  Nerva-Antonine  Principate
# 47         Unknown           Unknown         Gordian  Principate
# 40  Natural Causes           Disease         Gordian  Principate
# 24       Execution     Other Emperor         Severan  Principate
# 46  Natural Causes         Lightning         Gordian  Principate
# 43  Natural Causes           Disease         Gordian  Principate
# 8    Assassination     Other Emperor         Flavian  Principate
# 6    Assassination     Other Emperor         Flavian  Principate
# 35  Natural Causes           Disease         Gordian  Principate
# 31   Assassination  Praetorian Guard         Gordian  Principate
# 30   Assassination  Praetorian Guard         Gordian  Principate
# 44   Assassination          Own Army         Gordian  Principate
# 41         Unknown           Unknown         Gordian  Principate
# 19   Assassination  Praetorian Guard         Severan  Principate
# 7          Suicide     Other Emperor         Flavian  Principate
# 37   Assassination     Other Emperor         Gordian  Principate
# 20       Execution            Senate         Severan  Principate
# 29       Execution     Other Emperor         Gordian  Principate
# 28         Suicide     Other Emperor         Gordian  Principate
# 0              NaN               NaN             NaN         NaN
#
#                                                 notes               verif.who  \
# 1   birth, reign.start are BCE. Assign negative fo...  Reddit user zonination
# 15                                                NaN                     NaN
# 2   birth is BCE. Assign negative for correct ISO ...  Reddit user zonination
# 14                                                NaN                     NaN
# 49                                                NaN                     NaN
# 13                                                NaN                     NaN
# 22                 reign.start is only valid for year                     NaN
# 50                         birth, death are estimates                     NaN
# 17                                                NaN                     NaN
# 21                                                NaN                     NaN
# 18                 reign.start is only valid for year                     NaN
# 11                                                NaN                     NaN
# 39  birth, death, reign.end, reign.start are estim...                     NaN
# 4   birth is BCE. Assign negative for correct ISO ...  Reddit user zonination
# 5                                                 NaN  Reddit user zonination
# 26                                                NaN                     NaN
# 9                                                 NaN                     NaN
# 16                     death, reign.end are estimates                     NaN
# 38  birth, death, reign.end, reign.start are estim...                     NaN
# 45  birth, death, reign.end, reign.start are estim...                     NaN
# 32                                                NaN                     NaN
# 33                         reign.end is only estimate                     NaN
# 42                                                NaN                     NaN
# 3   assassination may have only involved the Praet...  Reddit user zonination
# 25                             birth is only estimate                     NaN
# 27  birth is only estimate. Death, reign.end are e...                     NaN
# 23                 reign.start is only valid for year                     NaN
# 10                                                NaN                     NaN
# 36  birth, death, reign.end, reign.start are estim...                     NaN
# 48  death, reign.end, reign.start are estimates. B...                     NaN
# 34  birth is only estimate. Reign.end is only esti...                     NaN
# 12                                                NaN                     NaN
# 47  death, reign.end, reign.start are estimates. B...                     NaN
# 40  birth, death, reign.end, reign.start are estim...                     NaN
# 24                       birth is only valid for year                     NaN
# 46  birth, death, reign.end, reign.start are estim...                     NaN
# 43             birth, death, reign.end are estimates.                     NaN
# 8                                                 NaN                     NaN
# 6   birth is BCE. Assign negative for correct ISO ...  Reddit user zonination
# 35  birth is only estimate. Reign.end is only esti...                     NaN
# 31                            birth is only estimate.                     NaN
# 30                            birth is only estimate.                     NaN
# 44  death, reign.end, reign.start are estimates. B...                     NaN
# 41  birth, death, reign.end, reign.start are estim...                     NaN
# 19                                                NaN                     NaN
# 7                                                 NaN                     NaN
# 37  birth, death, reign.end, reign.start are estim...                     NaN
# 20                     birth could also be 0137-02-02                     NaN
# 29                            birth is only estimate.                     NaN
# 28                            birth is only estimate.                     NaN
# 0                                                 NaN                     NaN
#
#        length
# 1   40.714488
# 15  22.725629
# 2   22.562773
# 14  20.994752
# 49  20.509365
# 13  19.530666
# 22  19.269310
# 50  19.085887
# 17  19.036423
# 21  17.888841
# 18  16.095410
# 11  15.090156
# 39  14.998089
# 4   13.800310
# 5   13.742406
# 26  13.024517
# 9    9.539426
# 16   8.026187
# 38   6.270136
# 45   6.128124
# 32   5.894427
# 33   5.701146
# 42   5.056204
# 3    3.869403
# 25   3.817095
# 27   3.306899
# 23   3.019519
# 10   2.309506
# 36   2.236154
# 48   2.050500
# 34   1.771485
# 12   1.369636
# 47   1.361021
# 40   1.355387
# 24   1.238862
# 46   0.850530
# 43   0.768039
# 8    0.752945
# 6    0.644828
# 35   0.373431
# 31   0.364438
# 30   0.357724
# 44   0.327575
# 41   0.324358
# 19   0.301751
# 7    0.266878
# 37   0.262309
# 20   0.260851
# 29   0.141922
# 28   0.130437
# 0    0.000000

# %%
df.query("name == 'Diocletian'").head(1)
# Out:
#     index        name                                          name.full  \
# 48     48  Diocletian  CAESAR GAIVS AVRELIVS VALERIVS DIOCLETIANVS AV...
#
#          birth       death birth.cty  birth.prv          rise       start  \
# 48  0244-12-22  0311-12-03    Salona  Dalmatian  Seized Power  284.885352
#
#           end           cause   killer        dynasty       era notes  \
# 48  305.34273  Natural Causes  Disease  Constantinian  Dominate   NaN
#
#    verif.who
# 48       NaN

# %%
pd.to_datetime("26-01-16", errors='coerce')
# Out:
# Timestamp('2016-01-26 00:00:00')

# %%
df
# Out:
#     index            name                                     name.full  \
# 0       1        Augustus         IMPERATOR CAESAR DIVI FILIVS AVGVSTVS
# 1       2        Tiberius  TIBERIVS CAESAR DIVI AVGVSTI FILIVS AVGVSTVS
# 2       3        Caligula       GAIVS IVLIVS CAESAR AVGVSTVS GERMANICVS
# 3       4        Claudius  TIBERIVS CLAVDIVS CAESAR AVGVSTVS GERMANICVS
# 4       5            Nero      NERO CLAVDIVS CAESAR AVGVSTVS GERMANICVS
# ..    ...             ...                                           ...
# 63     64   Valentinian I                FLAVIVS VALENTINIANVS AVGVSTVS
# 64     65          Valens                FLAVIVS IVLIVS VALENS AVGVSTVS
# 65     66         Gratian                    FLAVIVS GRATIANVS AVGVSTVS
# 66     67  Valentinian II       FLAVIVS VALENTINIANVS INVICTVS AVGVSTVS
# 67     68    Theodosius I                   FLAVIVS THEODOSIVS AVGVSTVS
#
#          birth       death birth.cty           birth.prv        rise  \
# 0   0062-09-23  0014-08-19      Rome              Italia  Birthright
# 1   0041-11-16  0037-03-16      Rome              Italia  Birthright
# 2   0012-08-31  0041-01-24   Antitum              Italia  Birthright
# 3   0009-08-01  0054-10-13  Lugdunum  Gallia Lugdunensis  Birthright
# 4   0037-12-15  0068-06-09   Antitum              Italia  Birthright
# ..         ...         ...       ...                 ...         ...
# 63  0321-07-03  0375-11-17   Cibalae            Pannonia    Election
# 64  0328-01-01  0378-08-09   Cibalae            Pannonia  Birthright
# 65  0359-04-18  0383-08-25   Sirmium            Pannonia  Birthright
# 66  0371-01-01  0392-05-15     Milan              Italia  Birthright
# 67  0347-01-11  0395-01-17     Cauca            Hispania  Birthright
#
#          start         end           cause         killer         dynasty  \
# 0    26.041068   14.632615   Assassination           Wife  Julio-Claudian
# 1    14.713210   37.207734   Assassination  Other Emperor  Julio-Claudian
# 2    37.213210   41.062971   Assassination         Senate  Julio-Claudian
# 3    41.065708   54.782854   Assassination           Wife  Julio-Claudian
# 4    54.782854   68.438569         Suicide         Senate  Julio-Claudian
# ..         ...         ...             ...            ...             ...
# 63  364.151780  375.877139  Natural Causes       Aneurism     Valentinian
# 64  364.240589  378.605236  Died in Battle  Opposing Army     Valentinian
# 65  367.591547  383.649042   Assassination       Own Army     Valentinian
# 66  375.877139  392.371663         Suicide        Unknown     Valentinian
# 67  379.000000  395.043806  Natural Causes        Disease      Theodosian
#
#            era                                              notes  \
# 0   Principate  birth, reign.start are BCE. Assign negative fo...
# 1   Principate  birth is BCE. Assign negative for correct ISO ...
# 2   Principate  assassination may have only involved the Praet...
# 3   Principate  birth is BCE. Assign negative for correct ISO ...
# 4   Principate                                                NaN
# ..         ...                                                ...
# 63    Dominate                                                NaN
# 64    Dominate                            birth is only estimate.
# 65    Dominate                       birth may also be 0359-05-23
# 66    Dominate                            birth is only estimate.
# 67    Dominate                                                NaN
#
#                   verif.who
# 0    Reddit user zonination
# 1    Reddit user zonination
# 2    Reddit user zonination
# 3    Reddit user zonination
# 4    Reddit user zonination
# ..                      ...
# 63  Reddit user ironicosity
# 64  Reddit user ironicosity
# 65  Reddit user ironicosity
# 66  Reddit user ironicosity
# 67  Reddit user ironicosity
#
# [68 rows x 16 columns]
