# %%
import requests, re, pandas as pd
from bs4 import BeautifulSoup

# %%
def get_statistical_themes():
    """
    Get Statistical Themes and IDs from TUIK
    
    This function retrieves the statistical themes and their corresponding IDs
    from the TUIK website. Each theme is associated with an ID, which can 
    be used to access specific datasets within that theme.
    
    :return: A list of tuples containing theme names and their corresponding IDs.
             Returns None if the request to the website fails.
    """
    url = "https://data.tuik.gov.tr/"
    response = requests.get(url)
    
    if response.status_code != 200:
        print(f"Failed to retrieve data: {response.status_code}")
        return None

    soup = BeautifulSoup(response.text, 'html.parser')
    themes = soup.find_all("div", class_="text-center")
    
    theme_names = []
    theme_ids = []
    
    for theme in themes:
        anchor = theme.find("a")
        if anchor:
            theme_name = anchor.text.strip()
            theme_id = anchor['href'].split('/')[-1]
            
            theme_names.append(theme_name)
            theme_ids.append(theme_id)

    return list(zip(theme_names, theme_ids))

# Test the function
themes = get_statistical_themes()
if themes:
    for theme_name, theme_id in themes:
        print(f"Theme Name: {theme_name}, Theme ID: {theme_id}")
# Out:
# Theme Name: Adalet ve Seçim, Theme ID: GetKategori?p=Adalet-ve-Secim-110
# Theme Name: Adalet ve Seçim, Theme ID: GetKategori?p=Adalet-ve-Secim-110
# Theme Name: Bilim, Teknoloji ve Bilgi Toplumu, Theme ID: GetKategori?p=Bilim,-Teknoloji-ve-Bilgi-Toplumu-102
# Theme Name: Çevre ve Enerji, Theme ID: GetKategori?p=Cevre-ve-Enerji-103
# Theme Name: Dış Ticaret, Theme ID: GetKategori?p=Dis-Ticaret-104
# Theme Name: Eğitim, Kültür, Spor ve Turizm, Theme ID: GetKategori?p=Egitim,-Kultur,-Spor-ve-Turizm-105
# Theme Name: Ekonomik Güven, Theme ID: GetKategori?p=Ekonomik-Guven-117
# Theme Name: Enflasyon ve Fiyat, Theme ID: GetKategori?p=Enflasyon-ve-Fiyat-106
# Theme Name: Gelir, Yaşam, Tüketim ve Yoksulluk, Theme ID: GetKategori?p=Gelir,-Yasam,-Tuketim-ve-Yoksulluk-107
# Theme Name: İnşaat ve Konut, Theme ID: GetKategori?p=Insaat-ve-Konut-116
# Theme Name: İstihdam, İşsizlik ve Ücret, Theme ID: GetKategori?p=Istihdam,-Issizlik-ve-Ucret-108
# Theme Name: Nüfus ve Demografi, Theme ID: GetKategori?p=Nufus-ve-Demografi-109
# Theme Name: Sağlık ve Sosyal Koruma, Theme ID: GetKategori?p=Saglik-ve-Sosyal-Koruma-101
# Theme Name: Sanayi, Theme ID: GetKategori?p=Sanayi-114
# Theme Name: Tarım, Theme ID: GetKategori?p=Tarim-111
# Theme Name: Ticaret ve Hizmet, Theme ID: GetKategori?p=Ticaret-ve-Hizmet-115
# Theme Name: Ulaştırma ve Haberleşme, Theme ID: GetKategori?p=Ulastirma-ve-Haberlesme-112
# Theme Name: Ulusal Hesaplar, Theme ID: GetKategori?p=Ulusal-Hesaplar-113

# %% [markdown]
# 1. We import the requests library to make a HTTP request to the TUIK website, and BeautifulSoup from the bs4 library to parse the HTML content.
# 2. We define a function get_statistical_themes() that retrieves and parses the HTML content from the TUIK website.
# 3. We find all div elements with the class text-center, which contain the statistical themes and their URLs.
# 4. We iterate through these elements, extract the theme names and IDs, and store them in separate lists.
# 5. We return a list of tuples containing the theme names and IDs.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_statistical_tables(theme_id):
    """
    Get the list of all statistical tables for a given theme from TUIK
    
    :param theme_id: ID of the data theme
    :return: A pandas DataFrame containing table names, data dates, and data file URLs.
    """
    url = 'https://data.tuik.gov.tr/Kategori/GetIstatistikselTablolar'
    payload = f'UstId={theme_id}&DilId=2&Page=1&Count=10000&Arsiv=false'
    headers = {'Content-Type': 'application/x-www-form-urlencoded'}

    response = requests.post(url, data=payload, headers=headers)
    
    if response.status_code != 200:
        print(f"Failed to retrieve data: {response.status_code}")
        return None

    soup = BeautifulSoup(response.text, 'html.parser')

    return soup
    
    # Extract table data
    tables = soup.find_all("table")
    if not tables:
        print("No tables found.")
        return None
    
    # Convert the first found table to a pandas DataFrame
    df = pd.read_html(str(tables[0]))[0]
    
    # Clean the DataFrame
    df = df.drop(columns=[2, 3]).dropna().reset_index(drop=True)
    df.columns = ['data_name', 'data_date']
    
    # Extract URLs
    anchors = soup.find_all("a", href=True)
    urls = [a['href'] for a in anchors if 'Bulten' not in a['href']]
    urls = [f"http://data.tuik.gov.tr{url}" for url in urls]
    
    # Add URLs to the DataFrame
    df['datafile_url'] = urls
    
    return df

# %%
# Test the function with a specific theme ID
soup = get_statistical_tables(108)
tables = soup.find_all("table")
if tables is not None:
    print(tables)
# Out:
# [<table aria-describedby="istatistikselTable_info" class="display table-hover dataTable no-footer" id="istatistikselTable" role="grid" style="width: 100%; font-size: 1.3rem;">
# <thead class="d-none">
# <tr>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# </thead>
# <tbody>
# <tr class="dtrg-group dtrg-start dtrg-level-0">
# <td>Monthly Results</td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="dtrg-group dtrg-start dtrg-level-1">
# <td>Labor Force Status of the Population</td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd" role="row" style="font-size: 1.2rem">
# <td width="80%">
# <svg class="tuik-icon mr-3 tuik-if-green" style="width: 18px; height: 18px">
# <title>İstatistiksel Tablolar</title>
# <use xlink:href="/img/SVG/symbol-defs.svg#tuik-icon-download_table"></use>
# </svg>
# <font color="red">Yeni</font>
#                                 Seasonally adjusted main labour force indicators (15+ age)
#                             </td>
# <td width="14%">
#                                 10 Ekim 2023
#                             </td>
# <td width="3%">
# <a data-placement="top" data-toggle="tooltip" href="/Bulten/DownloadIstatistikselTablo?p=MPF4QRhuYRKw75WOIeh3AQn2CB/BHQzhxkHVEPClX/GEUiogyIPe6u1dbXOA1OfT" title="İstatistiksel Tablolar">
# <img class="img-responsive float-right" height="20px" src="/img/SVG/excel.svg" width="20px"/>
# </a>
# </td>
# <td width="3%">
# <a data-placement="top" data-toggle="tooltip" href="/Bulten/DownloadIstatistikselTablo?p=H9GfHkAZxNxgSkvWPYvJUpgBTEANOtXWHzLHtvvgioiYmnbocTfM5bsAoFwzlVLY" title="Tablo Metaverisi">
# <img class="img-responsive float-right" height="20px" src="/img/SVG/word.svg" width="20px"/>
# </a>
# </td>
# </tr>
# <tr class="odd" role="row" style="font-size: 1.2rem">
# <td width="80%">
# <svg class="tuik-icon mr-3 tuik-if-green" style="width: 18px; height: 18px">
# <title>İstatistiksel Tablolar</title>
# <use xlink:href="/img/SVG/symbol-defs.svg#tuik-icon-download_table"></use>
# </svg>
# <font color="red">Yeni</font>
#                                 Seasonally adjusted main labour force indicators (15-24 age)
#                             </td>
# <td width="14%">
#                                 10 Ekim 2023
#                             </td>
# <td width="3%">
# <a data-placement="top" data-toggle="tooltip" href="/Bulten/DownloadIstatistikselTablo?p=S1ZvWpfB6iIP86vFy7MhAF3asfbnoN9BMeIFnvFCopinaorFQu5d0PO0du1tjAv2" title="İstatistiksel Tablolar">
# <img class="img-responsive float-right" height="20px" src="/img/SVG/excel.svg" width="20px"/>
# </a>
# </td>
# <td width="3%">
# <a data-placement="top" data-toggle="tooltip" href="/Bulten/DownloadIstatistikselTablo?p=Z3Jy8FthLmWMN9QkEh3kYCXWKTjw4uTycHVYFJjteYT76KR6rOdKGc6fHGY51q2p" title="Tablo Metaverisi">
# <img class="img-responsive float-right" height="20px" src="/img/SVG/word.svg" width="20px"/>
# </a>
# </td>
# </tr>
# <tr class="odd" role="row" style="font-size: 1.2rem">
# <td width="80%">
# <svg class="tuik-icon mr-3 tuik-if-green" style="width: 18px; height: 18px">
# <title>İstatistiksel Tablolar</title>
# <use xlink:href="/img/SVG/symbol-defs.svg#tuik-icon-download_table"></use>
# </svg>
# <font color="red">Yeni</font>
#                                 Main labour force indicators (15+ age)
#                             </td>
# <td width="14%">
#                                 10 Ekim 2023
#                             </td>
# <td width="3%">
# <a data-placement="top" data-toggle="tooltip" href="/Bulten/DownloadIstatistikselTablo?p=006BiNJPxKx8WlZHS0IKU2T2f8SM448ZbErV7kFHgTjPlhaKkgyWW391xURdiAqq" title="İstatistiksel Tablolar">
# <img class="img-responsive float-right" height="20px" src="/img/SVG/excel.svg" width="20px"/>
# </a>
# </td>
# <td width="3%">
# <a data-placement="top" data-toggle="tooltip" href="/Bulten/DownloadIstatistikselTablo?p=KvUn9DVxa8N5FcCP8UOkodybRz8xTI75vULaKRaLsFmFeTKqTGTVEtyDOqU8sUSr" title="Tablo Metaverisi">
# <img class="img-responsive float-right" height="20px" src="/img/SVG/word.svg" width="20px"/>
# </a>
# </td>
# </tr>
# <tr class="odd" role="row" style="font-size: 1.2rem">
# <td width="80%">
# <svg class="tuik-icon mr-3 tuik-if-green" style="width: 18px; height: 18px">
# <title>İstatistiksel Tablolar</title>
# <use xlink:href="/img/SVG/symbol-defs.svg#tuik-icon-download_table"></use>
# </svg>
# <font color="red">Yeni</font>
#                                 Main labour force indicators (15-24 age)
#                             </td>
# <td width="14%">
#                                 10 Ekim 2023
#                             </td>
# <td width="3%">
# <a data-placement="top" data-toggle="tooltip" href="/Bulten/DownloadIstatistikselTablo?p
title="Tablo Metaverisi">
# <img class="img-responsive float-right" height="20px" src="/img/SVG/word.svg" width="20px"/>
# </a>
# </td>
# </tr>
# <tr class="odd" role="row" style="font-size: 1.2rem">
# <td width="80%">
# <svg class="tuik-icon mr-3 tuik-if-green" style="width: 18px; height: 18px">
# <title>İstatistiksel Tablolar</title>
# <use xlink:href="/img/SVG/symbol-defs.svg#tuik-icon-download_table"></use>
# </svg>
#                                 Monthly average labour cost and components  by economic activity (2004, 2008)
#                             </td>
# <td width="14%">
#                                 29 Aralık 2009
#                             </td>
# <td width="3%">
# <a data-placement="top" data-toggle="tooltip" href="/Bulten/DownloadIstatistikselTablo?p=paXMZxMV5PLSMCTvmD1ZKt0yfSUsMQSoYiUPD8NQ2Fw96ElJ1a4qGk4lKzHq5Sxw" title="İstatistiksel Tablolar">
# <img class="img-responsive float-right" height="20px" src="/img/SVG/excel.svg" width="20px"/>
# </a>
# </td>
# <td width="3%">
# <a data-placement="top" data-toggle="tooltip" href="/Bulten/DownloadIstatistikselTablo?p=OVb1SFdk1wG9aH8utLQ8dShADCWLMQQB1RD2krB8/0ZFYcIvGpRrVzKQi89R2Hn4" title="Tablo Metaverisi">
# <img class="img-responsive float-right" height="20px" src="/img/SVG/word.svg" width="20px"/>
# </a>
# </td>
# </tr>
# <tr class="odd" role="row" style="font-size: 1.2rem">
# <td width="80%">
# <svg class="tuik-icon mr-3 tuik-if-green" style="width: 18px; height: 18px">
# <title>İstatistiksel Tablolar</title>
# <use xlink:href="/img/SVG/symbol-defs.svg#tuik-icon-download_table"></use>
# </svg>
#                                 Monthly average social security payments and components by economic activity (2004, 2008)
#                             </td>
# <td width="14%">
#                                 29 Aralık 2009
#                             </td>
# <td width="3%">
# <a data-placement="top" data-toggle="tooltip" href="/Bulten/DownloadIstatistikselTablo?p=q9/0BDqX3AiJ/sTKwiWWtBX/NUTQqL941Nwnk6tiwfzJdmuqUJuh5jxrE3rmuFLe" title="İstatistiksel Tablolar">
# <img class="img-responsive float-right" height="20px" src="/img/SVG/excel.svg" width="20px"/>
# </a>
# </td>
# <td width="3%">
# <a data-placement="top" data-toggle="tooltip" href="/Bulten/DownloadIstatistikselTablo?p=rnKvntp0DDVDB53zEQzZxbwUqf//7OGI1Evm8abJjGtKtGD08T3UhvRaLrSZsnz3" title="Tablo Metaverisi">
# <img class="img-responsive float-right" height="20px" src="/img/SVG/word.svg" width="20px"/>
# </a>
# </td>
# </tr>
# <tr class="dtrg-group dtrg-start dtrg-level-1">
# <td>Labour Cost by Collective Aggreament Status And Economic Activity</td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd" role="row" style="font-size: 1.2rem">
# <td width="80%">
# <svg class="tuik-icon mr-3 tuik-if-green" style="width: 18px; height: 18px">
# <title>İstatistiksel Tablolar</title>
# <use xlink:href="/img/SVG/symbol-defs.svg#tuik-icon-download_table"></use>
# </svg>
#                                 Monthly average social security payments and components by economic activity (2004, 2008)
#                             </td>
# <td width="14%">
#                                 29 Aralık 2009
#                             </td>
# <td width="3%">
# <a data-placement="top" data-toggle="tooltip" href="/Bulten/DownloadIstatistikselTablo?p=Bk5hymBAi9CYOgMLvaqufUqAG/yADVPRmn5HescPFGJLOZ8JnZ96QWzjircN06FM" title="İstatistiksel Tablolar">
# <img class="img-responsive float-right" height="20px" src="/img/SVG/excel.svg" width="20px"/>
# </a>
# </td>
# <td width="3%">
# <a data-placement="top" data-toggle="tooltip" href="/Bulten/DownloadIstatistikselTablo?p=2QmyfkbqVZDpdlw12qGMejMXstj0eiMhDMTkiqLQTr5OGg1XGLLfZE0meUDhZOZr" title="Tablo Metaverisi">
# <img class="img-responsive float-right" height="20px" src="/img/SVG/word.svg" width="20px"/>
# </a>
# </td>
# </tr>
# <tr class="odd" role="row" style="font-size: 1.2rem">
# <td width="80%">
# <svg class="tuik-icon mr-3 tuik-if-green" style="width: 18px; height: 18px">
# <title>İstatistiksel Tablolar</title>
# <use xlink:href="/img/SVG/symbol-defs.svg#tuik-icon-download_table"></use>
# </svg>
#                                 Actual weekly working hours and monthly average labour cost by economic activity (2004, 2008)
#                             </td>
# <td width="14%">
#                                 29 Aralık 2009
#                             </td>
# <td width="3%">
# <a data-placement="top" data-toggle="tooltip" href="/Bulten/DownloadIstatistikselTablo?p=wR0fetl2KMkWx6rszoUxLHNf6krvpUBq8YsiOvht/gjmFTve5b7V0BFlwEfGXpUJ" title="İstatistiksel Tablolar">
# <img class="img-responsive float-right" height="20px" src="/img/SVG/excel.svg" width="20px"/>
# </a>
# </td>
# <td width="3%">
# <a data-placement="top" data-toggle="tooltip" href="/Bulten/DownloadIstatistikselTablo?p=hK5rYA2muM1hN4Qg2zvwUjyoZVow1JLxeI//0knenv9c/OahNeIotQUj6dQUVpmq" title="Tablo Metaverisi">
# <img class="img-responsive float-right" height="20px" src="/img/SVG/word.svg" width="20px"/>
# </a>
# </td>
# </tr>
# <tr class="odd" role="row" style="font-size: 1.2rem">
# <td width="80%">
# <svg class="tuik-icon mr-3 tuik-if-green" style="width: 18px; height: 18px">
# <title>İstatistiksel Tablolar</title>
# <use xlink:href="/img/SVG/symbol-defs.svg#tuik-icon-download_table"></use>
# </svg>
#                                 Monthly average labour cost and components by economic activity (2004, 2008)
#                             </td>
# <td width="14%">
#                                 29 Aralık 2009
#                             </td>
# <td width="3%">
# <a data-placement="top" data-toggle="tooltip" href="/Bulten/DownloadIstatistikselTablo?p=rH04XYj0bMOBeZY4uuaro6N5hBRQqTcdP1I1NdcHXjElJwLtec/CZeD7Xptem6jD" title="İstatistiksel Tablolar">
# <img class="img-responsive float-right" height="20px" src="/img/SVG/excel.svg" width="20px"/>
# </a>
# </td>
# <td width="3%">
# <a data-placement="top" data-toggle="tooltip" href="/Bulten/DownloadIstatistikselTablo?p=keoaYC5gpmy/k1Yt1zdGop5x1dX5/x2bL5ZqVt7PxRN7H6WD1uOB5X7uT6RVmkZt" title="Tablo Metaverisi">
# <img class="img-responsive float-right" height="20px" src="/img/SVG/word.svg" width="20px"/>
# </a>
# </td>
# </tr>
# <tr class="dtrg-group dtrg-start dtrg-level-1">
# <td>Labour Cost by Collective Aggreament Status And Size Group Of the Enterprise</td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd" role="row" style="font-size: 1.2rem">
# <td width="80%">
# <svg class="tuik-icon mr-3 tuik-if-green" style="width: 18px; height: 18px">
# <title>İstatistiksel Tablolar</title>
# <use xlink:href="/img/SVG/symbol-defs.svg#tuik-icon-download_table"></use>
# </svg>
#                                 Monthly average social security paymants and components by size class of enterprise
#                             </td>
# <td width="14%">
#                                 29 Aralık 2009
#                             </td>
# <td width="3%">
# <a data-placement="top" data-toggle="tooltip" href="/Bulten/DownloadIstatistikselTablo?p=pYZ9tLsOHJAgADaOrDgthwf8OjMBaGvehTd3XK8IT1idL6U4r5BChhUb6wzP8nVd" title="İstatistiksel Tablolar">
# <img class="img-responsive float-right" height="20px" src="/img/SVG/excel.svg" width="20px"/>
# </a>
# </td>
# <td width="3%">
# <a data-placement="top" data-toggle="tooltip" href="/Bulten/DownloadIstatistikselTablo?p=KH20IjlRato/zdk4OpQ1Ija5aQURwuCNeBh5XtVacfK4fmCgnklmiGte/L0dMmyg" title="Tablo Metaverisi">
# <img class="img-responsive float-right" height="20px" src="/img/SVG/word.svg" width="20px"/>
# </a>
# </td>
# </tr>
# </tbody>
# </table>]

# %% [markdown]
# Parse table into dataframe

# %%
# Extract the first table into a list of DataFrame
df_tables = pd.read_html(str(tables[0]))

# %%
if tables:
    # Select the first table
    df = df_tables[0]

    # reset column names to index numbers
    df.columns = range(df.shape[1])
    
    # Select only the first two columns and remove rows where the second column is empty
    df = df.iloc[:, [0, 1]].dropna(subset=[1]).reset_index(drop=True)
    
    # Clean the first column by removing specific patterns of strings
    df[0] = df[0].apply(lambda x: re.sub(r'İstatistiksel Tablolar(Yeni)?\s*', '', x))

    # Remove `Yeni` from the first column
    df[0] = df[0].apply(lambda x: re.sub(r'Yeni\s*', '', x))
    
    print(df)
# Out:
#                                                      0               1
# 0    Seasonally adjusted main labour force indicato...    10 Ekim 2023
# 1    Seasonally adjusted main labour force indicato...    10 Ekim 2023
# 2               Main labour force indicators (15+ age)    10 Ekim 2023
# 3             Main labour force indicators (15-24 age)    10 Ekim 2023
# 4    Seasonally adjusted supplementary indicators f...    10 Ekim 2023
# ..                                                 ...             ...
# 219  Monthly average social security payments and c...  29 Aralık 2009
# 220  Monthly average social security payments and c...  29 Aralık 2009
# 221  Actual weekly working hours and monthly averag...  29 Aralık 2009
# 222  Monthly average labour cost and components by ...  29 Aralık 2009
# 223  Monthly average social security paymants and c...  29 Aralık 2009
#
# [224 rows x 2 columns]

# %%
# Using BeautifulSoup to parse the HTML and extract the needed data
rows = soup.find_all('tr')

# Set base_url for the datafile URLs
base_url = "http://data.tuik.gov.tr"

data = []
for row in rows:
    # Extracting the data name
    data_name = row.find('svg').find_next_sibling(string=True).strip() if row.find('svg') else None
    
    # Extracting the data date
    data_date = row.find('td', width="14%").text.strip() if row.find('td', width="14%") else None
    
    # Extracting the first URL (Excel file download link)
    excel_link = row.find('img', src="/img/SVG/excel.svg")
    datafile_url = base_url + excel_link.find_parent('a')['href'] if excel_link else None
    
    if data_name and data_date and datafile_url:  # Ensuring all extracted data is not None before appending
        data.append([data_name, data_date, datafile_url])

# Creating a DataFrame from the extracted data
df = pd.DataFrame(data, columns=['data_name', 'data_date', 'datafile_url'])

# Displaying the DataFrame
df.head()
# Out:
#                                    data_name        data_date  \
# 0             Labour Cost Indices (2015=100)  22 Ağustos 2023
# 1            Labour Input Indices (2015=100)  22 Ağustos 2023
# 2  Paid Employee Statistics (Trade-Services)  15 Ağustos 2023
# 3                   Paid Employee Statistics  15 Ağustos 2023
# 4        Paid Employee Statistics (Industry)  15 Ağustos 2023
#
#                                         datafile_url
# 0  http://data.tuik.gov.tr/Bulten/DownloadIstatis...
# 1  http://data.tuik.gov.tr/Bulten/DownloadIstatis...
# 2  http://data.tuik.gov.tr/Bulten/DownloadIstatis...
# 3  http://data.tuik.gov.tr/Bulten/DownloadIstatis...
# 4  http://data.tuik.gov.tr/Bulten/DownloadIstatis...

# %%
line = 5 

for row in rows:
    line -= 1
    if line < 0:
        break
    print(row, '\n')
# Out:
# <tr>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
#
# <tr class="dtrg-group dtrg-start dtrg-level-0">
# <td>Monthly Results</td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
#
# <tr class="dtrg-group dtrg-start dtrg-level-1">
# <td>Labor Force Status of the Population</td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
#
# <tr class="odd" role="row" style="font-size: 1.2rem">
# <td width="80%">
# <svg class="tuik-icon mr-3 tuik-if-green" style="width: 18px; height: 18px">
# <title>İstatistiksel Tablolar</title>
# <use xlink:href="/img/SVG/symbol-defs.svg#tuik-icon-download_table"></use>
# </svg>
# <font color="red">Yeni</font>
#                                 Seasonally adjusted main labour force indicators (15+ age)
#                             </td>
# <td width="14%">
#                                 10 Ekim 2023
#                             </td>
# <td width="3%">
# <a data-placement="top" data-toggle="tooltip" href="/Bulten/DownloadIstatistikselTablo?p=MPF4QRhuYRKw75WOIeh3AQn2CB/BHQzhxkHVEPClX/GEUiogyIPe6u1dbXOA1OfT" title="İstatistiksel Tablolar">
# <img class="img-responsive float-right" height="20px" src="/img/SVG/excel.svg" width="20px"/>
# </a>
# </td>
# <td width="3%">
# <a data-placement="top" data-toggle="tooltip" href="/Bulten/DownloadIstatistikselTablo?p=H9GfHkAZxNxgSkvWPYvJUpgBTEANOtXWHzLHtvvgioiYmnbocTfM5bsAoFwzlVLY" title="Tablo Metaverisi">
# <img class="img-responsive float-right" height="20px" src="/img/SVG/word.svg" width="20px"/>
# </a>
# </td>
# </tr>
#
# <tr class="odd" role="row" style="font-size: 1.2rem">
# <td width="80%">
# <svg class="tuik-icon mr-3 tuik-if-green" style="width: 18px; height: 18px">
# <title>İstatistiksel Tablolar</title>
# <use xlink:href="/img/SVG/symbol-defs.svg#tuik-icon-download_table"></use>
# </svg>
# <font color="red">Yeni</font>
#                                 Seasonally adjusted main labour force indicators (15-24 age)
#                             </td>
# <td width="14%">
#                                 10 Ekim 2023
#                             </td>
# <td width="3%">
# <a data-placement="top" data-toggle="tooltip" href="/Bulten/DownloadIstatistikselTablo?p=S1ZvWpfB6iIP86vFy7MhAF3asfbnoN9BMeIFnvFCopinaorFQu5d0PO0du1tjAv2" title="İstatistiksel Tablolar">
# <img class="img-responsive float-right" height="20px" src="/img/SVG/excel.svg" width="20px"/>
# </a>
# </td>
# <td width="3%">
# <a data-placement="top" data-toggle="tooltip" href="/Bulten/DownloadIstatistikselTablo?p=Z3Jy8FthLmWMN9QkEh3kYCXWKTjw4uTycHVYFJjteYT76KR6rOdKGc6fHGY51q2p" title="Tablo Metaverisi">
# <img class="img-responsive float-right" height="20px" src="/img/SVG/word.svg" width="20px"/>
# </a>
# </td>
# </tr>

# %%
row.find('svg').find_next_sibling(string=True).strip() if row.find('svg') else None
# Out:
# 'Monthly average social security paymants and components by size class of enterprise'

# %%
# get first item
df.iloc[0]['datafile_url']
# Out:
# 'http://data.tuik.gov.tr/Bulten/DownloadIstatistikselTablo?p=IEq9LM7MfrAwOb5YcoB7UjFDHQd1PUwIiSU50kW6smxf3paFfW587jMnbQxawoTT'

# %% [markdown]
# ---

# %% [markdown]
# Now we've got urls for each statistics table in a given theme. We can use these urls to download the tables and parse them into dataframes.

# %%
# get first item
df.iloc[0]['datafile_url']

# download linked Excel file and read into a DataFrame
df_excel = pd.read_excel(df.iloc[0]['datafile_url'])

# %%
df_excel
# Out:
#     Tüketim harcaması türlerinin harcamaya göre sıralı %20'lik gruplara göre dağılımı, Türkiye, 2002-2022  \
# 0    Distribution of quintiles ordered by expenditu...
# 1                                                  NaN
# 2                                                  NaN
# 3                               Anket yılı Survey year
# 4                                                  NaN
# ..                                                 ...
# 268  COICOP sınıflaması 2022 yılında hem ECOICOP he...
# 269  (1)  Yeni nüfus projeksiyonları 2007 yılından ...
# 270  (2) Örneklem tasarımında 2014 yılından itibare...
# 271  (3) ECOICOP sınıflaması kullanılmıştır - ECOIC...
# 272  (4) COICOP 2018 sınıflaması kullanılmıştır - C...
#
#                              Unnamed: 1    Unnamed: 2  \
# 0                                   NaN           NaN
# 1                                   NaN           NaN
# 2                                   NaN           NaN
# 3    Harcama türleri\nExpenditure types           NaN
# 4                                   NaN  Toplam Total
# ..                                  ...           ...
# 268                                 NaN           NaN
# 269                                 NaN           NaN
# 270                                 NaN           NaN
# 271                                 NaN           NaN
# 272                                 NaN           NaN
#
#                                            Unnamed: 3  \
# 0                                                 NaN
# 1                                                 NaN
# 2    Harcama grubu - Quintiles ordered by expenditure
# 3                                                 NaN
# 4                             1. %20 \nFirst quintile
# ..                                                ...
# 268                                               NaN
# 269                                               NaN
# 270                                               NaN
# 271                                               NaN
# 272                                               NaN
#
#                       Unnamed: 4                  Unnamed: 5  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4    2. %20      Second quintile  3. %20      Third quintile
# ..                           ...                         ...
# 268                          NaN                         NaN
# 269                          NaN                         NaN
# 270                          NaN                         NaN
# 271                          NaN                         NaN
# 272                          NaN                         NaN
#
#                       Unnamed: 6                 Unnamed: 7
# 0                            NaN                        (%)
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4    4. %20      Fourth quintile  5. %20      Last quintile
# ..                           ...                        ...
# 268                          NaN                        NaN
# 269                          NaN                        NaN
# 270                          NaN                        NaN
# 271                          NaN                        NaN
# 272                          NaN                        NaN
#
# [273 rows x 8 columns]

# %%
# Select the first table
df = tables[0]
    
# Select only the first two columns and remove rows where the second column is empty
df = df.iloc[:, [0, 1]].dropna(subset=[1]).reset_index(drop=True)

# Clean the first column by removing specific patterns of strings
df[0] = df[0].apply(lambda x: re.sub(r'İstatistiksel Tablolar(Yeni)?\s*', '', x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/joshhellings/Documents/ECO/RADataHub/ECOAPI/Turkey/automated/statistical_themes.ipynb Cell 12 line 5
#       <a href='vscode-notebook-cell:/Users/joshhellings/Documents/ECO/RADataHub/ECOAPI/Turkey/automated/statistical_themes.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> df = tables[0]
#       <a href='vscode-notebook-cell:/Users/joshhellings/Documents/ECO/RADataHub/ECOAPI/Turkey/automated/statistical_themes.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a> # Select only the first two columns and remove rows where the second column is empty
# ----> <a href='vscode-notebook-cell:/Users/joshhellings/Documents/ECO/RADataHub/ECOAPI/Turkey/automated/statistical_themes.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a> df = df.iloc[:, [0, 1]].dropna(subset=[1]).reset_index(drop=True)
#       <a href='vscode-notebook-cell:/Users/joshhellings/Documents/ECO/RADataHub/ECOAPI/Turkey/automated/statistical_themes.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a> # Clean the first column by removing specific patterns of strings
#       <a href='vscode-notebook-cell:/Users/joshhellings/Documents/ECO/RADataHub/ECOAPI/Turkey/automated/statistical_themes.ipynb#X16sZmlsZQ%3D%3D?line=7'>8</a> df[0] = df[0].apply(lambda x: re.sub(r'İstatistiksel Tablolar(Yeni)?\s*', '', x))
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Parse the HTML content
soup = BeautifulSoup(response.text, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/6p/njxvnljx3b36_1d566nq5mjh0000gn/T/ipykernel_76765/1879614787.py in ?()
#       8     # Select the first table
#       9     df = tables[0]
#      10
#      11     # Select only the first two columns and remove rows where the second column is empty
# ---> 12     df = df.iloc[:, [0, 1]].dropna(subset=[1]).reset_index(drop=True)
#      13
#      14     # Clean the first column by removing specific patterns of strings
#      15     df[0] = df[0].apply(lambda x: re.sub(r'İstatistiksel Tablolar(Yeni)?\s*', '', x))
#
# ~/miniforge3/envs/web_scrape/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6403             ax = self._get_axis(agg_axis)
#    6404             indices = ax.get_indexer_for(subset)
#    6405             check = indices == -1
#    6406             if check.any():
# -> 6407                 raise KeyError(np.array(subset)[check].tolist())
#    6408             agg_obj = self.take(indices, axis=agg_axis)
#    6409
#    6410         if thresh is not no_default:
#
# KeyError: [1]

# %%
# Extract table data
tables = soup.find_all("table")

# %%
pd.read_html(str(tables[0]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/joshhellings/Documents/ECO/RADataHub/ECOAPI/Turkey/automated/statistical_themes.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell:/Users/joshhellings/Documents/ECO/RADataHub/ECOAPI/Turkey/automated/statistical_themes.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> pd.read_html(str(tables[0]))
#
# File ~/miniforge3/envs/web_scrape/lib/python3.10/site-packages/pandas/io/html.py:1212, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend)
#    1208 check_dtype_backend(dtype_backend)
#    1210 io = stringify_path(io)
# -> 1212 return _parse(
#    1213     flavor=flavor,
#    1214     io=io,
#    1215     match=match,
#    1216     header=header,
#    1217     index_col=index_col,
#    1218     skiprows=skiprows,
#    1219     parse_dates=parse_dates,
#    1220     thousands=thousands,
#    1221     attrs=attrs,
#    1222     encoding=encoding,
#    1223     decimal=decimal,
#    1224     converters=converters,
#    1225     na_values=na_values,
#    1226     keep_default_na=keep_default_na,
#    1227     displayed_only=displayed_only,
#    1228     extract_links=extract_links,
#    1229     dtype_backend=dtype_backend,
#    1230 )
#
# File ~/miniforge3/envs/web_scrape/lib/python3.10/site-packages/pandas/io/html.py:1001, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, **kwargs)
#     999 else:
#    1000     assert retained is not None  # for mypy
# -> 1001     raise retained
#    1003 ret = []
#    1004 for table in tables:
#
# File ~/miniforge3/envs/web_scrape/lib/python3.10/site-packages/pandas/io/html.py:981, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, **kwargs)
#     978 p = parser(io, compiled_match, attrs, encoding, displayed_only, extract_links)
#     980 try:
# --> 981     tables = p.parse_tables()
#     982 except ValueError as caught:
#     983     # if `io` is an io-like object, check if it's seekable
#     984     # and try to rewind it before trying the next parser
#     985     if hasattr(io, "seekable") and io.seekable():
#
# File ~/miniforge3/envs/web_scrape/lib/python3.10/site-packages/pandas/io/html.py:257, in _HtmlFrameParser.parse_tables(self)
#     249 def parse_tables(self):
#     250     """
#     251     Parse and return all tables from the DOM.
#     252
#    (...)
#     255     list of parsed (header, body, footer) tuples from tables.
#     256     """
# --> 257     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     258     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File ~/miniforge3/envs/web_scrape/lib/python3.10/site-packages/pandas/io/html.py:629, in _BeautifulSoupHtml5LibFrameParser._parse_tables(self, doc, match, attrs)
#     626     unique_tables.add(table)
#     628 if not result:
# --> 629     raise ValueError(f"No tables found matching pattern {repr(match.pattern)}")
#     630 return result
#
# ValueError: No tables found matching pattern '.+'

# %%
theme_id = 107
url = 'https://data.tuik.gov.tr/Kategori/GetIstatistikselTablolar'
payload = f'UstId={theme_id}&DilId=2&Page=1&Count=10000&Arsiv=false'
headers = {'Content-Type': 'application/x-www-form-urlencoded'}

response = requests.post(url, data=payload, headers=headers)

# %%
response.text
# save response.text to file as html
with open('response.txt', 'w') as f:
    f.write(response.text)

# Parse the HTML content
soup = BeautifulSoup(response.text, 'html.parser')
# save response.text to file as html

# %%
# Load the new HTML content from the provided .txt file
with open("response.txt", "r", encoding="utf-8") as file:
    html_content = file.read()

# Parse the HTML content with BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# Extract the table
tables = pd.read_html(html_content)

# Check if we have any tables and display the first one if available
if tables:
    df = tables[0]
    display(df.head())
else:
    print("No tables found in the HTML content.")
# Out:
#                                           Unnamed: 0       Unnamed: 1  \
# 0                                                  -              NaN
# 1  Household Consumption Expenditure Statistics (...              NaN
# 2  İstatistiksel Tablolar  Distribution of Quinti...  09 Haziran 2023
# 3  İstatistiksel Tablolar  Distribution of Househ...  09 Haziran 2023
# 4  İstatistiksel Tablolar  Distribution of Househ...  09 Haziran 2023
#
#    Unnamed: 2  Unnamed: 3
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
tables
# Out:
# [                                           Unnamed: 0       Unnamed: 1  \
#  0                                                   -              NaN
#  1   Household Consumption Expenditure Statistics (...              NaN
#  2   İstatistiksel Tablolar  Distribution of Quinti...  09 Haziran 2023
#  3   İstatistiksel Tablolar  Distribution of Househ...  09 Haziran 2023
#  4   İstatistiksel Tablolar  Distribution of Househ...  09 Haziran 2023
#  ..                                                ...              ...
#  95  İstatistiksel Tablolar  The distribution of sp...     12 Ocak 2016
#  96  İstatistiksel Tablolar  The distribution of in...     12 Ocak 2016
#  97  İstatistiksel Tablolar  The distribution of pe...     12 Ocak 2016
#  98  İstatistiksel Tablolar  Yaşlı bakımı ve sıklığ...     12 Ocak 2016
#  99  İstatistiksel Tablolar  Average activity time ...     12 Ocak 2016
#
#      Unnamed: 2  Unnamed: 3
#  0          NaN         NaN
#  1          NaN         NaN
#  2          NaN         NaN
#  3          NaN         NaN
#  4          NaN         NaN
#  ..         ...         ...
#  95         NaN         NaN
#  96         NaN         NaN
#  97         NaN         NaN
#  98         NaN         NaN
#  99         NaN         NaN
#
#  [100 rows x 4 columns]]

# %%
# Clean the DataFrame by selecting and renaming the relevant columns
cleaned_df = df.iloc[:, [0, 1]].copy()
cleaned_df.columns = ['data_name', 'data_date']

# Clean the data_name column to remove unwanted characters or strings
cleaned_df['data_name'] = cleaned_df['data_name'].str.replace('İstatistiksel Tablolar', '', regex=False).str.strip()

# Display the cleaned DataFrame
cleaned_df.head()
# Out:
#                                            data_name        data_date
# 0                                                  -              NaN
# 1  Household Consumption Expenditure Statistics (...              NaN
# 2  Distribution of Quintiles Ordered by Expenditu...  09 Haziran 2023
# 3  Distribution of Household Consumption Expendit...  09 Haziran 2023
# 4  Distribution of Household Consumption Expendit...  09 Haziran 2023

# %%
# Filter out rows where the data_date column is NaN, as these rows likely represent subcategories
cleaned_df = cleaned_df.dropna(subset=['data_date']).reset_index(drop=True)

# Clean the data_name column by removing unwanted patterns
cleaned_df['data_name'] = cleaned_df['data_name'].str.replace(r'\s*İstatistiksel Tablolar(Yeni)?\s*', '', regex=True)

# %%
# Select only the first two columns and remove rows where the second column is empty
df = df.iloc[:, [0, 1]].dropna(subset=[1]).reset_index(drop=True)

# Clean the first column by removing specific patterns of strings
df[0] = df[0].apply(lambda x: re.sub(r'İstatistiksel Tablolar(Yeni)?\s*', '', x))

# %%
cleaned_df
# Out:
#                                             data_name        data_date
# 0   Distribution of Quintiles Ordered by Expenditu...  09 Haziran 2023
# 1   Distribution of Household Consumption Expendit...  09 Haziran 2023
# 2   Distribution of Household Consumption Expendit...  09 Haziran 2023
# 3   Distribution of Household Consumption Expendit...  09 Haziran 2023
# 4   Distribution of Household Consumption Expendit...  09 Haziran 2023
# ..                                                ...              ...
# 74  The distribution of sports activities done or ...     12 Ocak 2016
# 75  The distribution of intensity status of daily ...     12 Ocak 2016
# 76  The distribution of persons who do not have en...     12 Ocak 2016
# 77  Yaşlı bakımı ve sıklığının cinsiyete göre dağı...     12 Ocak 2016
# 78  Average activity time per person by type of ac...     12 Ocak 2016
#
# [79 rows x 2 columns]

# %%
# Clean the DataFrame by selecting and renaming the relevant columns
cleaned_df = df.iloc[:, [0, 1]].copy()
cleaned_df.columns = ['data_name', 'data_date']

# Clean the data_name column to remove unwanted characters or strings
cleaned_df['data_name'] = cleaned_df['data_name'].str.replace('İstatistiksel Tablolar', '', regex=False).str.strip()

# Display the cleaned DataFrame
display(cleaned_df.head())

# Now let's extract the URLs from the anchor tags in the HTML content
anchors = soup.find_all('a', href=True)
urls = [a['href'] for a in anchors]

# Display the first few URLs to inspect their structure
urls[:5]
# Out:
#                                            data_name        data_date
# 0                                                  -              NaN
# 1  Household Consumption Expenditure Statistics (...              NaN
# 2  Distribution of Quintiles Ordered by Expenditu...  09 Haziran 2023
# 3  Distribution of Household Consumption Expendit...  09 Haziran 2023
# 4  Distribution of Household Consumption Expendit...  09 Haziran 2023
# ['/Bulten/DownloadIstatistikselTablo?p=ioIn886qTBBxZ04d6ADzoen12l8Jgf/nwNiesH5bOD9SEjfjmnV1Px0pu7U4F1jk',
#  '/Bulten/DownloadIstatistikselTablo?p=IZarm6K/Mu88EoNXhQvRr76vq0y3fJQkvlrAo6FTUoooc3T79jyr8KRZcruUU/cd',
#  '/Bulten/DownloadIstatistikselTablo?p=259m50DUpYS9GZbtWZO86fOJT4VR/jHbS7tW7w4V/TMJeY91SYAxPvxDfXevHD3/',
#  '/Bulten/DownloadIstatistikselTablo?p=D3mYcO6Ez3eUFdjjsJhh/a12JDbZKIqUrf6bithoKW8Ca5RAJpzsGc4LbkBAJGFg',
#  '/Bulten/DownloadIstatistikselTablo?p=FM9xB8s/0kXi7bPMZO4aPj/8noaXlpCCOUq3Tlvn8F0zGJ55JXjB/KfR04wday0r']

# %%
len(urls)
# Out:
# 157

# %%
base_url = "http://data.tuik.gov.tr"

# %%
# Find the container element that holds the table rows
table_container = soup.find('tbody')

# Extract each row within the table container
table_rows = table_container.find_all('tr') if table_container else []

# Extract URLs associated with each row
row_urls = []
for row in table_rows:
    anchor = row.find('a', href=True)
    if anchor:
        url = base_url + anchor['href']
        row_urls.append(url)
    else:
        # Add None for rows without URLs to keep the same length
        row_urls.append(None)

# Filter out None values to get the final list of URLs
row_urls = list(filter(None, row_urls))

# Add the URLs to the cleaned DataFrame
if len(row_urls) == len(cleaned_df):
    cleaned_df['datafile_url'] = row_urls
else:
    print("The number of URLs does not match the number of rows in the DataFrame.")

# Display the DataFrame with URLs
cleaned_df.head()
# Out:
# The number of URLs does not match the number of rows in the DataFrame.
#                                            data_name        data_date
# 0                                                  -              NaN
# 1  Household Consumption Expenditure Statistics (...              NaN
# 2  Distribution of Quintiles Ordered by Expenditu...  09 Haziran 2023
# 3  Distribution of Household Consumption Expendit...  09 Haziran 2023
# 4  Distribution of Household Consumption Expendit...  09 Haziran 2023

# %%
#  '/Bulten/DownloadIstatistikselTablo?p=10LWge4xxjTuI4292vgYkHVEH3gmliussZPgt/H/wqnM8A/zDHH1pqXZ7TBPdCLV',
#  '/Bulten/DownloadIstatistikselTablo?p=7kDLKYZWV7NoUegxzPu5R1EzvcnOIHez5JMEYyc4Ly4AAEVajgqGG6dpNwueOWCE',
#  '/Bulten/DownloadIstatistikselTablo?p=z5VvutBJVpp2bDGXR7ScaKVD5opaxSyo7ysa66RwkzUP/8gvFGfUZre1FZC32J22',
#  '/Bulten/DownloadIstatistikselTablo?p=QR4pFKzboDDbAA4VDobJuKKPbdcod/b6NKS2EHOn9/AMboGkKpOiV742Mku9BfbD',
#  '/Bulten/DownloadIstatistikselTablo?p=V4pP/HP8KzmEKcCmYped66znTdr//xcSD8Tx08xYpoRjeFhcWX3dw1VOEjwvoPoM',
#  '/Bulten/DownloadIstatistikselTablo?p=3mHJ0256gcVVqY4INchrkRL6/UGVCmeuHkLCygb1iBBlVZXBeQhZgAmy7rzIV03X',
#  '/Bulten/DownloadIstatistikselTablo?p=fWIqGPY4W25x5odVC8KeSBgqQOy914ZK/sladcidLELT21tBorsyOydbZfic0OqZ',
#  '/Bulten/DownloadIstatistikselTablo?p=fG0J8LYDV1Urlq8SdbCiKz5nWjYEc6VZ9CN7JPYD5RcPrJDYvpviX5aoteLxZSqe',
#  '/Bulten/DownloadIstatistikselTablo?p=9Vkir95IPP5yGtB9VfkBtZGbpYf22HE1dv2R1YPyr1U6o7baN6XINVZpLfrT7YPP',
#  '/Bulten/DownloadIstatistikselTablo?p=dUl2dEqtsDICwIjYlJNAFC3B97nv/KLfWgUw2qRKeMeoYgKELrYpV6BYYfCQ3kbb',
#  '/Bulten/DownloadIstatistikselTablo?p=rFkN4Pufa0M/wlDjvqFI8eTYgLDm3jLXiC3ZEg3J8P7DC448GyWz4WlAsshtB4Dt',
#  '/Bulten/DownloadIstatistikselTablo?p=Djqqll0SP5133bFWKv6WtHs3ol1UX6Au4rSu8pzkTL4k2yhV/Z/YV6gorSTrUPLv',
#  '/Bulten/DownloadIstatistikselTablo?p=W6FvqNEx/FOAWM3GG89f1rBRmeDVBvMwcYhaDm4p5Jf47seoLoPcnJeyrsvcelGu',
#  '/Bulten/DownloadIstatistikselTablo?p=wX6ptJGmnLJaaAAR0KoT3oZjns3wzqPmSc0nhusXW573sMDXEO1yEJMJL0wB3xVx',
#  '/Bulten/DownloadIstatistikselTablo?p=RzL3JDrqGN8gVJbrlkxUcUgxwGHhUboKFb/TQVwtmIihAQY0JjhUhp089l4wOHwP',
#  '/Bulten/DownloadIstatistikselTablo?p=h0sv5n1jvBTWHUFahr3HmmIjGk9MOwjl6zS9ewDWTkNu2SQKIidZGHMOzD4aiI3t',
#  '/Bulten/DownloadIstatistikselTablo?p=0KjVsPH3MCN7JbP7LEbZGhxDwJKRysqojylDiTF59LY7p25GnohSBRLdF2ZF69ts',
#  '/Bulten/DownloadIstatistikselTablo?p=rtGBFLGdZYmEe3/3eECa5ds76Qii3b1XxVYdg6sGcJOA0q73mTrabIAXLWVgKcCH',
#  '/Bulten/DownloadIstatistikselTablo?p=NS3BBrbLv3X3QzvqEgBy2LlsmhWrwQ4L2fIbo75FOh3PlD/l1ilVnWwpMgbJdduS',
#  '/Bulten/DownloadIstatistikselTablo?p=B3hg2Jji11WQKffyqd0ixhqp01WwuSsR0YJZKbk1FDisydLK4p5XAGYTpc9klAYY',
#  '/Bulten/DownloadIstatistikselTablo?p=AmmqgUQQ8gVSiT9OjkZoVZ5CRlwpdsVdBAsneW0PdnL2YTb6FDKPh9ezgC5qbaVF',
#  '/Bulten/DownloadIstatistikselTablo?p=otWSavp86dHf/h18C9OT7uba3Mffxysl5WXKseIz5KCghZzk5VC/uDmZdyUyMCKf',
#  '/Bulten/DownloadIstatistikselTablo?p=H6uwurdUOSrvqoMED1tPm3Vcr67xuwJvBIrdXm1P95qtV0dYQJojMSGldFE965Tf',
#  '/Bulten/DownloadIstatistikselTablo?p=LOhNpg7Vma4WWIwzLWqo9wgGG461V4Try6rL5eRzHAwAE1HGrBtFwUVgw0q06n5q',
#  '/Bulten/DownloadIstatistikselTablo?p=yh3Le7xf8OHUj7lzA8dyPm9YDUaKYsnFwCbM7iU99wGCACRTpyahWV2VupSo8i1p',
#  '/Bulten/DownloadIstatistikselTablo?p=BD7uHZUJgEBfqxL6U1wvYhYcNEg9UsdbKiAaUVwncc6xDk8p3MvK8Pi3bUggpNro',
#  '/Bulten/DownloadIstatistikselTablo?p=yewjb8E8gSzzn8mfTjssCAcI5lo/0nZu2CxkfOmM2Sf6Zx7jU15AzFBwqCkpyLKD',
#  '/Bulten/DownloadIstatistikselTablo?p=vIpUN0gMrda8sTzBaukKch4GDNY0FdIX1Yq1EBxEUScbNQg4Qj7PR9rOdPKGani8',
#  '/Bulten/DownloadIstatistikselTablo?p=GeGIY5w/QRu0R8eRVl3f7QEay2vuvEN7dub5s2ijJT/pYRhh2lAgTPEX8oUa4ufi',
#  '/Bulten/DownloadIstatistikselTablo?p=0/7lh21YegWgxGdpGTTH7tfye3BLoLze8ws6lk2UB88JVTzEKLpVlELkHmdohDET',
#  '/Bulten/DownloadIstatistikselTablo?p=u1wBZRBGuEzpZ2yc4fztQ1y6SMzXVHUjMBfR/VxZIx/MyPKTIpxTAbnpXizDbnhL',
#  '/Bulten/DownloadIstatistikselTablo?p=/r5jWg3pLPV2C0pGDbMfSavA2i9myK1TR3fLwp4NfN4ooYcivxjPYsfDcymXeCpU',
#  '/Bulten/DownloadIstatistikselTablo?p=V15DTphQjHnbRx6WQAURMy1hsBffN/4C61cAQOlRfywRignj9xlVM66g8gHRHmjg',
#  '/Bulten/DownloadIstatistikselTablo?p=ktpVXAeUxtEmRY65Po9zXbpr5nwYs8auwLL2ppcEHFm6HraD2MhPwFEYHhdIadVF',
#  '/Bulten/DownloadIstatistikselTablo?p=Z74T1YeoKJlfHS2N4vEyCf0l81n6AwZ6aLxoFLAa7pWzNASfCJbTCYrI2us4S5yi',
#  '/Bulten/DownloadIstatistikselTablo?p=KqRNNlgBrAHfDl2Ubrge49UD1hWxMmP3yllGjdZbQuUK9At8x3vciYir4UQzLvl/',
