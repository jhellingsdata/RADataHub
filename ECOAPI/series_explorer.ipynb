# %%
import pandas as pd, altair as alt

# %%
# import metadata staging
df = pd.read_csv('/Users/joshhellings/Documents/ECO/api/metadata-staging.csv')

# %%
len(df)
# Out:
# 211

# %%
print('Unique Countries: ', df['country'].nunique())
print('Unique Series: ', df['ecoSeries'].nunique())
df['ecoSeries'].value_counts()
# Out:
# Unique Countries:  24
# Unique Series:  27
# infl     23
# unem     21
# popu     20
# impo     19
# expo     19
# grow     18
# empl     14
# debt     12
# gdpp     11
# gdpa     10
# prod      7
# inac      6
# wage      6
# empd      6
# ineq      5
# gdp       2
# part      2
# inter     1
# conf      1
# petro     1
# capit     1
# by10      1
# undr      1
# house     1
# fert      1
# esta      1
# umpd      1
# Name: ecoSeries, dtype: int64

# %%
# plot the number of each series on a chart
alt.Chart(df).mark_bar().encode(
    alt.X('ecoSeries:N', sort='-y', axis=alt.Axis(labelAngle=-30, labelOffset=5)),
    alt.Y('count(ecoSeries):Q', title='Country Count', axis=alt.Axis(labelFontSize=11, zindex=1, gridOpacity=0.3)),
)
# Out:
# alt.Chart(...)

# %%
# find the country which doesn't have an inflation `infl` series.
# 1. create list of countries with inflation series
# 2. create list of all countries
# 3. find the difference

infl_countries = df[df['ecoSeries'] == 'infl']['country'].unique()

all_countries = df['country'].unique()

set(all_countries) - set(infl_countries)
# Out:
# {'bra'}

# %%
# `by10`: 10-year bond yield

# 
# `capit`: Capital Formation, gross fixed (Iran only)
# `petro`: Petrochemical Industry Output (Iran only)
# `conf`: Consumer Confidence (Mexicon only)
# `esta`: Real estate investment (China only)
# `inter`: Interest rate, base rate (Mexico only)

df[df['ecoSeries'] == 'inter']
# Out:
#     country_full country ecoSeries  \
# 133       Mexico     mex     inter
#
#                                              ecoAPI  \
# 133  https://api.economicsobservatory.com/mex/inter
#
#                                               localAPI localSeries  \
# 133  https://en.www.inegi.org.mx/app/api/indicadore...      182022
#
#     localDataset          Title                                      SubTitle  \
# 133          BIE  Interest rate  Base rate, % | Source: INEGI through ECO API
#
#                                               API_base  ...  \
# 133  https://en.www.inegi.org.mx/app/api/indicadore...  ...
#
#                      description units date field multiplier date_keys  \
# 133  Central Bank Interest Rates     %    %   NaN          1       NaN
#
#     value_keys  filter  orient  use_cache
# 133        NaN     NaN     NaN          0
#
# [1 rows x 23 columns]

# %%
df[df['ecoSeries'] == 'gdp']['description'].values
# Out:
# array([nan,
#        'Seasonally adjusted Gross Domestic Product at current prices (EUR mn)Ã”Ã¸Î©'],
#       dtype=object)

# %%
# `gdpa`: constant 2015 US$
df[df['ecoSeries'] == 'gdpa'].head(2)
# Out:
#    country_full country ecoSeries  \
# 6    Bangladesh     bgd      gdpa
# 38     DR Congo     cod      gdpa
#
#                                            ecoAPI  \
# 6   https://api.economicsobservatory.com/bgd/gdpa
# 38  https://api.economicsobservatory.com/cod/gdpa
#
#                                              localAPI localSeries  \
# 6   https://raw.githubusercontent.com/EconomicsObs...         NaN
# 38  https://raw.githubusercontent.com/EconomicsObs...         NaN
#
#    localDataset Title                                       SubTitle  \
# 6           NaN   GDP    2015 USD | Source: BBS (WB) through ECO API
# 38          NaN   GDP  2015 USD | Source: World Bank through ECO API
#
#                                              API_base  ...     description  \
# 6   https://raw.githubusercontent.com/EconomicsObs...  ...  GDP (2015 US$)
# 38  https://raw.githubusercontent.com/EconomicsObs...  ...  GDP (2015 US$)
#
#                 units date field multiplier date_keys value_keys  filter  \
# 6   constant 2015 US$  NaN   NaN          1       NaN        NaN     NaN
# 38  constant 2015 US$  NaN   NaN          1       NaN        NaN     NaN
#
#     orient  use_cache
# 6      NaN          1
# 38     NaN          1
#
# [2 rows x 23 columns]

# %%
# Find number of series grouping by country
df_count = df.groupby('country')['ecoSeries'].nunique().sort_values(ascending=False)
df_count
# Out:
# country
# gbr    12
# idn    12
# ind    10
# jpn    10
# usa    10
# can    10
# tur    10
# cod    10
# tha    10
# eth    10
# pak    10
# phl     9
# vnm     9
# bgd     9
# fra     9
# egy     9
# nga     8
# deu     8
# mex     7
# rus     7
# chn     7
# irn     6
# bra     5
# aus     4
# Name: ecoSeries, dtype: int64

# %%
pd.DataFrame(df_count)
# Out:
#          ecoSeries
# country
# gbr             12
# idn             12
# ind             10
# jpn             10
# usa             10
# can             10
# tur             10
# cod             10
# tha             10
# eth             10
# pak             10
# phl              9
# vnm              9
# bgd              9
# fra              9
# egy              9
# nga              8
# deu              8
# mex              7
# rus              7
# chn              7
# irn              6
# bra              5
# aus              4

# %%
# save df_count to csv
df_count.to_csv('series-count.csv')

# %%
# count number of `use cache` series
df[df['use_cache'] == True]['ecoSeries'].count()
# Out:
# 156
