# %%
import pandas as pd
import numpy as np
import altair as alt
import eco_style
alt.themes.enable('light')
# Out:
# ThemeRegistry.enable('light')

# %%
df
# Out:
#             date       value         party  group
# 0     01/01/1923  100.000000  Conservative      0
# 1     01/02/1923  100.503020  Conservative      0
# 2     01/03/1923  100.863103  Conservative      0
# 3     01/04/1923  101.438269  Conservative      0
# 4     01/05/1923  101.174317  Conservative      0
# ...          ...         ...           ...    ...
# 1125  01/10/2016  100.066738  Conservative     14
# 1126  01/11/2016   99.720897  Conservative     14
# 1127  01/12/2016   99.977694  Conservative     14
# 1128  01/01/2017  100.393233  Conservative     14
# 1129  01/02/2017  100.479841  Conservative     14
#
# [1130 rows x 4 columns]

# %%
df = pd.read_csv("econ.obs.csv")
df = df.rename(columns={"rebased_share_index": "value"})
df = df[['date', 'value', 'party', 'group']]

df['date'] = pd.to_datetime(df['date'], dayfirst=True)

df

base = alt.Chart(df).encode(
    x=alt.X('date:T', title=""),
    y=alt.Y('value:Q', title="Share index", 
            axis=alt.Axis(titleY=-17),
            scale=alt.Scale(domain=[80, 140])),
    color=alt.Color('party:N', title="Party", 
                    legend=alt.Legend(title="", orient="none", labelFontSize=12, titleFontSize=14, direction="horizontal", legendY=-15),
                    scale=alt.Scale(domain=['Conservative', 'Labour', 'Coalition'], range=['#0087DC', 'hsl(2, 75.30%, 49.20%)', 'rgb(199, 35, 214)'])),
    detail='group:N'
)

lines = base.mark_line()

chart = lines

chart = chart.properties(
    width=450,
    height=300
)

chart.save("fig1.png", scale_factor=3.0)
chart.save("fig1.json")
chart
# Out:
# /Users/finn/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/finn/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/finn/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
df.party.value_counts()
# Out:
# party
# Conservative    610
# Labour          398
# Coalition       122
# Name: count, dtype: int64
